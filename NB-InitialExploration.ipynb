# %% [markdown]
# # DfE Public API Test

# %% [markdown]
# https://dfe-analytical-services.github.io/explore-education-statistics-api-docs/getting-started/creating-advanced-data-set-queries

# %% [markdown]
# This code is was written in Microsoft Fabric using a spark cluster. Within fabric there is a default spark instance called spark.
#
#  If running outside of Fabric you may have to create a spark instance and pass it into the class.
#
# To do this on a local machine you would need to first install pyspark using:
#
# ```
# pip install pyspark
# ```
# Then:
#
# ```
# from pyspark.sql import SparkSession
#
# spark = (SparkSession.builder
#     .appName("Local Spark App Without Cluster")
#     .master("local[*]")  # Use all available CPU cores for parallelism
#     .getOrCreate())
# ```
#
# You'd also have to change display to df.show() and write delta tables to path rather than saving to a table name.

# %% [markdown]
# ## Processing Functions

# %%
import requests
import json
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, BooleanType, ArrayType, MapType
from pyspark.sql.functions import explode, col, map_keys, map_values
from urllib.parse import urlencode, urlparse, parse_qs, urlunparse
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 3, Finished, Available, Finished)

# %%
class DfE_API:
    def __init__(self, data_set_id, spark_session = spark, api_version="1.0"):
        self.spark = spark_session
        self._data_set_id = data_set_id
        self._api_version = api_version
        self.base_endpoint_url = f"https://test.statistics.api.education.gov.uk/api/v{api_version}/data-sets/{data_set_id}" 
        
        # Get summary and meta data for data set.
        self.data_set_summary_json = self._get_data_set_summary_json()
        self.data_set_meta_json = self._get_data_set_meta_json()

        # Populate dataframes from meta data.
        self.indicators_df = self._process_indicators_from_meta()
        self.geographic_levels_df = self._process_geographic_levels_from_meta()
        self.locations_df = self._process_locations_from_meta()
        self.time_periods_df = self._process_time_periods_from_meta()
        self.filters_df = self._process_filters_from_meta()

        # Place holder instant variables.
        self.query_response_json = None
        self.raw_query_response_df = None
        self.query_response_df = None

    # Core API calls:

    def _fetch_all_results(self, base_url, query_body):
        combined_results = []
        current_page = 1
        query_json = query_body
        
        while True:
            # Add or update the page parameter in the URL
            if current_page > 1:
                query_json['page'] = current_page
            
            response = requests.post(base_url, json=query_json)
            response.raise_for_status()  # Check for HTTP request errors
            
            data = response.json()

            max_pages = data['paging']['totalPages']

            print(f"Retrived page {current_page} of {max_pages}.")
            combined_results.extend(data['results'])
            
            # Check if we reached the last page
            if current_page >= max_pages:
                break
            
            current_page += 1  # Move to the next page
        
        return combined_results

    def _get_data_set_summary_json(self):
        response = requests.get(self.base_endpoint_url)
        return response.json()

    def _get_data_set_meta_json(self):
        url = f"{self.base_endpoint_url}/meta"
        response = requests.get(url)
        return response.json() 

    def post_data_set_query(self, query_body, data_set_version = None):
        # Uses POST to send query in body. At least one indicator must be specificed
        url = f"{self.base_endpoint_url}/query"
        if data_set_version is not None:
            url = f"{url}?dataSetVersion={data_set_version}"

        results = self._fetch_all_results(url, query_body)
        self.query_response_json = results
        self._process_query_response()
        return "Query Suceeded"

    def _process_indicators_from_meta(self):
        # Process Indicators from Meta Data JSON Response
        indicators_schema = StructType([
            StructField("id", StringType(), True),
            StructField("column", StringType(), True),
            StructField("label", StringType(), True),
            StructField("decimalPlaces", IntegerType(), True)
        ])

        indicators_df = self.spark.createDataFrame(self.data_set_meta_json["indicators"], schema=indicators_schema)
        return indicators_df

    def _process_geographic_levels_from_meta(self):
        # Process Geographic Levels from Meta Data JSON Response
        geographic_levels_schema = StructType([
            StructField("code", StringType(), True),
            StructField("label", StringType(), True)
        ])

        geographic_levels_df = self.spark.createDataFrame(self.data_set_meta_json["geographicLevels"], schema=geographic_levels_schema)
        return geographic_levels_df       

    def _process_locations_from_meta(self):
        # Process Locations from Meta Data JSON Response
        locations_schema = StructType([
            StructField("level", StructType([
                StructField("code", StringType(), True),
                StructField("label", StringType(), True)
            ]), True),
            StructField("options", ArrayType(
                StructType([
                    StructField("id", StringType(), True),
                    StructField("label", StringType(), True),
                    StructField("code", StringType(), True)
                ])
            ), True)
        ])

        locations_df = self.spark.createDataFrame(self.data_set_meta_json["locations"], schema=locations_schema)

        # Flatten the options array in locations
        flattened_locations_df = (locations_df
            .withColumn("option", explode("options"))
            .withColumn("option_id", col("option.id"))
            .withColumn("option_label", col("option.label"))
            .withColumn("option_code", col("option.code"))
            .withColumn("level_code", col("level.code"))
            .withColumn("level_label", col("level.label"))
            .drop("options", "option", "level")
            )
        
        return flattened_locations_df   

   
    def _process_time_periods_from_meta(self):
        # Process Time Periods from Meta Data JSON Response
        time_periods_schema = StructType([
            StructField("code", StringType(), True),
            StructField("period", StringType(), True),
            StructField("label", StringType(), True)
        ])

        time_periods_df = self.spark.createDataFrame(self.data_set_meta_json["timePeriods"], schema=time_periods_schema)
        return time_periods_df                                                                                      

    def _process_filters_from_meta(self):
        # Process Filters from Meta Data JSON Response
        filters_schema = StructType([
            StructField("id", StringType(), True),
            StructField("column", StringType(), True),
            StructField("label", StringType(), True),
            StructField("options", ArrayType(
                StructType([
                    StructField("id", StringType(), True),
                    StructField("label", StringType(), True),
                    StructField("isAggregate", BooleanType(), True)
                ])
            ), True)
        ])
        filters_df = self.spark.createDataFrame(self.data_set_meta_json["filters"], schema=filters_schema)

        # Flatten the options array
        flattened_filters_df = (filters_df
                                    .withColumn("option", explode("options"))
                                    .withColumn("option_id", col("option.id"))
                                    .withColumn("option_label", col("option.label"))
                                    .withColumn("is_aggregate", col("option.isAggregate"))
                                    .drop("options", "option")
            )

        return flattened_filters_df

    def _process_query_response(self):
        # Process response from query
        
        # Define schema for results
        results_schema = StructType([
            StructField("timePeriod", StructType([
                StructField("code", StringType(), True),
                StructField("period", StringType(), True)
            ])),
            StructField("geographicLevel", StringType(), True),
            StructField("locations", MapType(StringType(), StringType()), True),
            StructField("filters", MapType(StringType(), StringType()), True),
            StructField("values", MapType(StringType(), StringType()), True)
        ])

        # Create DataFrame for results
        #.get("results", [])
        results_df = spark.createDataFrame(self.query_response_json, schema=results_schema)

        # Expand and alias columns
        # This assumes there is only one filter pair and location pair per row.
        # Explodes the values out for a row per indicator.
        self.raw_query_response_df = results_df.select(
                col("timePeriod.code").alias("period_code"),
                col("timePeriod.period").alias("period"),
                col("geographicLevel").alias("geographic_level"),
                map_keys(col("locations")).getItem(0).alias("location_level_code"),
                map_values(col("locations")).getItem(0).alias("location_option_id"),
                map_keys(col("filters")).getItem(0).alias("filter_id"),
                map_values(col("filters")).getItem(0).alias("filter_option_id"),
                explode("values").alias("indicator_id", "value")
            )
        
        # Join onto meta data dataframes to produce final result.
        self.query_response_df = (
            self.raw_query_response_df
                .join(
                    self.indicators_df,
                    (self.raw_query_response_df["indicator_id"] == self.indicators_df["id"]),
                    how="left"
                )
                .join(
                    self.locations_df,
                    (self.raw_query_response_df["location_level_code"] == self.locations_df["level_code"]) &
                    (self.raw_query_response_df["location_option_id"] == self.locations_df["option_id"]),
                    how="left"
                )
                .join(
                    self.filters_df,
                    (self.raw_query_response_df["filter_id"] == self.filters_df["id"]) &
                    (self.raw_query_response_df["filter_option_id"] == self.filters_df["option_id"]),
                    how="left"
                )
                .join(
                    self.time_periods_df,
                    (self.raw_query_response_df["period_code"] == self.time_periods_df["code"]) &
                    (self.raw_query_response_df["period"] == self.time_periods_df["period"]),
                    how="left"
                )
                .join(
                    self.geographic_levels_df,
                    (self.raw_query_response_df["geographic_level"] == self.geographic_levels_df["code"]),
                    how="left"
                )
                .select(
                    self.indicators_df['label'].alias("indictor_label"),
                    self.locations_df["level_label"].alias("location_level_label"),
                    self.locations_df["option_label"].alias("location_option_label"),
                    self.time_periods_df["label"].alias("period_label"),
                    self.geographic_levels_df["label"].alias("geographic_level_label"),
                    self.filters_df["label"].alias("filter_label"),
                    self.filters_df["option_label"].alias("filter_option_label"),
                    self.filters_df["is_aggregate"],
                    self.raw_query_response_df['value']
                )
            )
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 4, Finished, Available, Finished)

# %% [markdown]
# ## Test data set A: Pupil absence

# %%
data_set_id = "e1ae9201-2fff-d376-8fa3-bd3c3660d4c8"
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 5, Finished, Available, Finished)

# %%
SetA = DfE_API(data_set_id, spark_session = spark)
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 6, Finished, Available, Finished)

# %% [markdown]
# ### Dataset Summary

# %%
print(json.dumps(SetA.data_set_summary_json, indent=4))
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 7, Finished, Available, Finished)
# {
#     "id": "e1ae9201-2fff-d376-8fa3-bd3c3660d4c8",
#     "title": "Pupil absence",
#     "summary": "Test file",
#     "status": "Published",
#     "latestVersion": {
#         "version": "1.0",
#         "published": "2024-10-21T12:15:26.171566+00:00",
#         "totalResults": 12,
#         "file": {
#             "id": "5296244d-5487-4416-bec0-43ed4b50b72a"
#         },
#         "timePeriods": {
#             "start": "2021/22",
#             "end": "2023/24"
#         },
#         "geographicLevels": [
#             "National"
#         ],
#         "filters": [
#             "Type of school"
#         ],
#         "indicators": [
#             "Number of overall absence sessions",
#             "Number of pupil enrolments",
#             "Number of sessions possible"
#         ]
#     }
# }

# %% [markdown]
# ### Dataset Meta Data

# %%
display(SetA.filters_df)
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e29d4f88-05a5-4a72-8ba8-5f6833a16a28)

# %%
display(SetA.indicators_df)
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, f5829cc6-423d-4a49-ad1f-e466bab8371d)

# %%
display(SetA.locations_df)
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, f04b5d18-8f52-4084-9ed1-20e31d6b4a0a)

# %%
display(SetA.geographic_levels_df)
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4a45dfc9-1c66-442a-9720-1793879300d4)

# %%
display(SetA.time_periods_df)
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 128436d0-3176-4a84-be96-29eb12c24760)

# %% [markdown]
# ### Example Dataset POST Query

# %%
data = {
    "criteria": {
        "and": [
            {
                "timePeriods": {
                    "in": [
                        {"period": "2023/2024","code": "AY"},
                        {"period": "2023/2024","code": "AY"}
                    ]
                }
            },
            {
                "locations": {
                    "eq": {"level": "NAT","code": "E92000001"}
                }
            }
        ]
    },
    "indicators": ["dPe0Z", "OBXCL", "7YFXo"]
}
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 13, Finished, Available, Finished)

# %%
SetA.post_data_set_query(data)
#print(json.dumps(response_json, indent=4))
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 14, Finished, Available, Finished)
# Retrived page 1 of 1.
# 'Query Suceeded'

# %%
display(SetA.query_response_df)
# Out:
# StatementMeta(, 9269343a-a3a3-45cf-ba3d-7121fe405269, 15, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 0dd2de97-877b-4ecc-a1e2-12ec2c740aff)

# %%
SetA.query_response_df.write.format("delta").mode("overwrite").saveAsTable("LH_DFE.raw.set_a")
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 24, Finished, Available, Finished)

# %% [markdown]
# ## Test data set B: Pupil Attendance Sessions

# %%
version = "1.0"
data_set_id = "57b69201-033a-2c77-a19f-abcce2b11341"
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 16, Finished, Available, Finished)

# %%
SetB = DfE_API(data_set_id, version)
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 17, Finished, Available, Finished)

# %% [markdown]
# ### Data Set Summary

# %%
print(json.dumps(SetB.data_set_summary_json, indent=4))
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 18, Finished, Available, Finished)
# {
#     "id": "57b69201-033a-2c77-a19f-abcce2b11341",
#     "title": "Pupil attendance sessions",
#     "summary": "",
#     "status": "Published",
#     "latestVersion": {
#         "version": "1.0",
#         "published": "2024-10-22T22:34:44.356583+00:00",
#         "totalResults": 3315543,
#         "file": {
#             "id": "cc6745d0-d4bb-4871-bf26-a9ed653a66f1"
#         },
#         "timePeriods": {
#             "start": "2023 Week 37",
#             "end": "2024 Week 25"
#         },
#         "geographicLevels": [
#             "Local authority",
#             "National",
#             "Regional"
#         ],
#         "filters": [
#             "Attendance status",
#             "Attendance type",
#             "Day number",
#             "Establishment phase",
#             "Reason"
#         ],
#         "indicators": [
#             "Session count",
#             "Session percent",
#             "Session scaled"
#         ]
#     }
# }

# %% [markdown]
# ### Dataset Meta Data

# %%
print(json.dumps(SetB.data_set_meta_json, indent=4))
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 19, Finished, Available, Finished)
# {
#     "filters": [
#         {
#             "id": "5Zdi9",
#             "column": "attendance_status",
#             "label": "Attendance status",
#             "hint": "",
#             "options": [
#                 {
#                     "id": "qGJjG",
#                     "label": "Absence"
#                 },
#                 {
#                     "id": "a2NLP",
#                     "label": "Administrative code"
#                 },
#                 {
#                     "id": "BfP7J",
#                     "label": "Attendance"
#                 },
#                 {
#                     "id": "zvUFQ",
#                     "label": "Late sessions"
#                 },
#                 {
#                     "id": "kaNhs",
#                     "label": "Not a possible session"
#                 },
#                 {
#                     "id": "u9Mo4",
#                     "label": "Possible sessions"
#                 }
#             ]
#         },
#         {
#             "id": "tdEm5",
#             "column": "attendance_type",
#             "label": "Attendance type",
#             "hint": "",
#             "options": [
#                 {
#                     "id": "XH4fK",
#                     "label": "Administrative code"
#                 },
#                 {
#                     "id": "TuxPJ",
#                     "label": "Approved educational activity"
#                 },
#                 {
#                     "id": "cZO31",
#                     "label": "Authorised"
#                 },
#                 {
#                     "id": "5Tsdi",
#                     "label": "Late"
#                 },
#                 {
#                     "id": "tj0Em",
#                     "label": "Present"
#                 },
#                 {
#                     "id": "fzaYF",
#                     "label": "Total",
#                     "isAggregate": true
#                 },
#                 {
#                     "id": "jgoAM",
#                     "label": "Unauthorised"
#                 }
#             ]
#         },
#         {
#             "id": "fyYFZ",
#             "column": "day_number",
#             "label": "Day number",
#             "hint": "",
#             "options": [
#                 {
#                     "id": "emDuS",
#                     "label": "1"
#                 },
#                 {
#                     "id": "TuNPJ",
#                     "label": "2"
#                 },
#                 {
#                     "id": "hLOyW",
#                     "label": "3"
#                 },
#                 {
#                     "id": "mUq9K",
#                     "label": "4"
#                 },
#                 {
#                     "id": "gIyO9",
#                     "label": "5"
#                 },
#                 {
#                     "id": "AOhGK",
#                     "label": "Total",
#                     "isAggregate": true
#                 }
#             ]
#         },
#         {
#             "id": "juAMt",
#             "column": "education_phase",
#             "label": "Establishment phase",
#             "hint": "",
#             "options": [
#                 {
#                     "id": "V0D5X",
#                     "label": "Primary"
#                 },
#                 {
#                     "id": "Poqeb",
#                     "label": "Secondary"
#                 },
#                 {
#                     "id": "1rPi3",
#                     "label": "Special"
#                 },
#                 {
#                     "id": "dPE0Z",
#                     "label": "Total",
#                     "isAggregate": true
#                 }
#             ]
#         },
#         {
#             "id": "eNuSW",
#             "column": "attendance_reason",
#             "label": "Reason",
#             "hint": "",
#             "options": [
#                 {
#                     "id": "u9Oo4",
#                     "label": "B education off site"
#                 },
#                 {
#                     "id": "l8ScB",
#                     "label": "C authorised other"
#                 },
#                 {
#                     "id": "UhYRF",
#                     "label": "D dual registration"
#                 },
#                 {
#                     "id": "o47mX",
#                     "label": "E authorised excluded"
#                 },
#                 {
#                     "id": "rQkNj",
#                     "label": "G unauthorised holiday"
#                 },
#                 {
#                     "id": "GCsgr",
#                     "label": "H authorised holiday"
#                 },
#                 {
#                     "id": "3se8u",
#                     "label": "I authorised illness"
#                 },
#                 {
#                     "id": "SdgVx",
#                     "label": "J interview"
#                 },
#                 {
#                     "id": "yW5aB",
#                     "label": "L present late before registers closed"
#                 },
#                 {
#                     "id": "RySka",
#                     "label": "M authorised medical dental"
#                 },
#                 {
#                     "id": "bqZtT",
#                     "label": "N no reason yet"
#                 },
#                 {
#                     "id": "Db3Qe",
#                     "label": "Not attending planned closed"
#                 },
#                 {
#                     "id": "emJuS",
#                     "label": "O other unauthorised"
#                 },
#                 {
#                     "id": "5TYdi",
#                     "label": "P approved sporting activity"
#                 },
#                 {
#                     "id": "4kdUZ",
#                     "label": "Present"
#                 },
#                 {
#                     "id": "mU59K",
#                     "label": "Present am"
#                 },
#                 {
#                     "id": "0evT5",
#                     "label": "Present pm"
#                 },
#                 {
#                     "id": "WcR2b",
#                     "label": "R authorised religious observance"
#                 },
#                 {
#                     "id": "EADqF",
#                     "label": "S authorised study leave"
#                 },
#                 {
#                     "id": "Qt6wb",
#                     "label": "T authorised grt absence"
#                 },
#                 {
#                     "id": "9Ru4v",
#                     "label": "Total",
#                     "isAggregate": true
#                 },
#                 {
#                     "id": "23Llz",
#                     "label": "U unauthorised late after registers closed"
#                 },
#                 {
#                     "id": "PoTeb",
#                     "label": "V educational visit trip"
#                 },
#                 {
#                     "id": "NwNDC",
#                     "label": "W work experience"
#                 },
#                 {
#                     "id": "wqtbx",
#                     "label": "Y not attending enforced closure"
#                 },
#                 {
#                     "id": "oU4mX",
#                     "label": "Z not attending not on roll"
#                 }
#             ]
#         }
#     ],
#     "indicators": [
#         {
#             "id": "tj0Em",
#             "column": "session_count",
#             "label": "Session count"
#         },
#         {
#             "id": "fzaYF",
#             "column": "session_percent",
#             "label": "Session percent"
#         },
#         {
#             "id": "jgoAM",
#             "column": "session_scaled",
#             "label": "Session scaled"
#         }
#     ],
#     "geographicLevels": [
#         {
#             "code": "LA",
#             "label": "Local authority"
#         },
#         {
#             "code": "NAT",
#             "label": "National"
#         },
#         {
#             "code": "REG",
#             "label": "Regional"
#         }
#     ],
#     "locations": [
#         {
#             "level": {
#                 "code": "LA",
#                 "label": "Local authority"
#             },
#             "options": [
#                 {
#                     "id": "V0D5X",
#                     "label": "Barking and Dagenham",
#                     "code": "E09000002",
#                     "oldCode": "301"
#                 },
#                 {
#                     "id": "Poqeb",
#                     "label": "Barnet",
#                     "code": "E09000003",
#                     "oldCode": "302"
#                 },
#                 {
#                     "id": "HJPzL",
#                     "label": "Barnsley",
#                     "code": "E08000016",
#                     "oldCode": "370"
#                 },
#                 {
#                     "id": "5Zdi9",
#                     "label": "Bath and North East Somerset",
#                     "code": "E06000022",
#                     "oldCode": "800"
#                 },
#                 {
#                     "id": "ENqFR",
#                     "label": "Bedford",
#                     "code": "E06000055",
#                     "oldCode": "822"
#                 },
#                 {
#                     "id": "1rPi3",
#                     "label": "Bexley",
#                     "code": "E09000004",
#                     "oldCode": "303"
#                 },
#                 {
#                     "id": "u9Mo4",
#                     "label": "Birmingham",
#                     "code": "E08000025",
#                     "oldCode": "330"
#                 },
#                 {
#                     "id": "6jrfe",
#                     "label": "Blackburn with Darwen",
#                     "code": "E06000008",
#                     "oldCode": "889"
#                 },
#                 {
#                     "id": "0kT5D",
#                     "label": "Blackpool",
#                     "code": "E06000009",
#                     "oldCode": "890"
#                 },
#                 {
#                     "id": "2alzG",
#                     "label": "Bolton",
#                     "code": "E08000001",
#                     "oldCode": "350"
#                 },
#                 {
#                     "id": "Dt8Qe",
#                     "label": "Bournemouth, Christchurch and Poole",
#                     "code": "E06000058",
#                     "oldCode": "839"
#                 },
#                 {
#                     "id": "ugo41",
#                     "label": "Bracknell Forest",
#                     "code": "E06000036",
#                     "oldCode": "867"
#                 },
#                 {
#                     "id": "jgoAM",
#                     "label": "Bradford",
#                     "code": "E08000032",
#                     "oldCode": "380"
#                 },
#                 {
#                     "id": "dPE0Z",
#                     "label": "Brent",
#                     "code": "E09000005",
#                     "oldCode": "304"
#                 },
#                 {
#                     "id": "SGVxt",
#                     "label": "Brighton and Hove",
#                     "code": "E06000043",
#                     "oldCode": "846"
#                 },
#                 {
#                     "id": "RaVka",
#                     "label": "Bristol, City of",
#                     "code": "E06000023",
#                     "oldCode": "801"
#                 },
#                 {
#                     "id": "u9Oo4",
#                     "label": "Bromley",
#                     "code": "E09000006",
#                     "oldCode": "305"
#                 },
#                 {
#                     "id": "w61bx",
#                     "label": "Buckinghamshire",
#                     "code": "E06000060",
#                     "oldCode": "825"
#                 },
#                 {
#                     "id": "P0ebW",
#                     "label": "Bury",
#                     "code": "E08000002",
#                     "oldCode": "351"
#                 },
#                 {
#                     "id": "emDuS",
#                     "label": "Calderdale",
#                     "code": "E08000033",
#                     "oldCode": "381"
#                 },
#                 {
#                     "id": "7HJXo",
#                     "label": "Cambridgeshire",
#                     "code": "E10000003",
#                     "oldCode": "873"
#                 },
#                 {
#                     "id": "l8ScB",
#                     "label": "Camden",
#                     "code": "E09000007",
#                     "oldCode": "202"
#                 },
#                 {
#                     "id": "Qiwb4",
#                     "label": "Central Bedfordshire",
#                     "code": "E06000056",
#                     "oldCode": "823"
#                 },
#                 {
#                     "id": "eFuSW",
#                     "label": "Cheshire East",
#                     "code": "E06000049",
#                     "oldCode": "895"
#                 },
#                 {
#                     "id": "5fdi9",
#                     "label": "Cheshire West and Chester",
#                     "code": "E06000050",
#                     "oldCode": "896"
#                 },
#                 {
#                     "id": "AOhGK",
#                     "label": "City of London",
#                     "code": "E09000001",
#                     "oldCode": "201"
#                 },
#                 {
#                     "id": "mV9KC",
#                     "label": "Cornwall",
#                     "code": "E06000052",
#                     "oldCode": "908"
#                 },
#                 {
#                     "id": "bjstT",
#                     "label": "County Durham",
#                     "code": "E06000047",
#                     "oldCode": "840"
#                 },
#                 {
#                     "id": "XH4fK",
#                     "label": "Coventry",
#                     "code": "E08000026",
#                     "oldCode": "331"
#                 },
#                 {
#                     "id": "UhYRF",
#                     "label": "Croydon",
#                     "code": "E09000008",
#                     "oldCode": "306"
#                 },
#                 {
#                     "id": "mRd9K",
#                     "label": "Cumberland",
#                     "code": "E06000063",
#                     "oldCode": "942"
#                 },
#                 {
#                     "id": "IzBzg",
#                     "label": "Darlington",
#                     "code": "E06000005",
#                     "oldCode": "841"
#                 },
#                 {
#                     "id": "BT7J3",
#                     "label": "Derby",
#                     "code": "E06000015",
#                     "oldCode": "831"
#                 },
#                 {
#                     "id": "IfJBz",
#                     "label": "Derbyshire",
#                     "code": "E10000007",
#                     "oldCode": "830"
#                 },
#                 {
#                     "id": "iDq6X",
#                     "label": "Devon",
#                     "code": "E10000008",
#                     "oldCode": "878"
#                 },
#                 {
#                     "id": "C7SId",
#                     "label": "Doncaster",
#                     "code": "E08000017",
#                     "oldCode": "371"
#                 },
#                 {
#                     "id": "e9vuS",
#                     "label": "Dorset",
#                     "code": "E06000059",
#                     "oldCode": "838"
#                 },
#                 {
#                     "id": "TuxPJ",
#                     "label": "Dudley",
#                     "code": "E08000027",
#                     "oldCode": "332"
#                 },
#                 {
#                     "id": "o47mX",
#                     "label": "Ealing",
#                     "code": "E09000009",
#                     "oldCode": "307"
#                 },
#                 {
#                     "id": "CpId1",
#                     "label": "East Riding of Yorkshire",
#                     "code": "E06000011",
#                     "oldCode": "811"
#                 },
#                 {
#                     "id": "6QGrf",
#                     "label": "East Sussex",
#                     "code": "E10000011",
#                     "oldCode": "845"
#                 },
#                 {
#                     "id": "rQkNj",
#                     "label": "Enfield",
#                     "code": "E09000010",
#                     "oldCode": "308"
#                 },
#                 {
#                     "id": "0uyT5",
#                     "label": "Essex",
#                     "code": "E10000012",
#                     "oldCode": "881"
#                 },
#                 {
#                     "id": "gIyO9",
#                     "label": "Gateshead",
#                     "code": "E08000037",
#                     "oldCode": "390"
#                 },
#                 {
#                     "id": "HvezL",
#                     "label": "Gloucestershire",
#                     "code": "E10000013",
#                     "oldCode": "916"
#                 },
#                 {
#                     "id": "GCsgr",
#                     "label": "Greenwich",
#                     "code": "E09000011",
#                     "oldCode": "203"
#                 },
#                 {
#                     "id": "3se8u",
#                     "label": "Hackney",
#                     "code": "E09000012",
#                     "oldCode": "204"
#                 },
#                 {
#                     "id": "it6Xr",
#                     "label": "Halton",
#                     "code": "E06000006",
#                     "oldCode": "876"
#                 },
#                 {
#                     "id": "SdgVx",
#                     "label": "Hammersmith and Fulham",
#                     "code": "E09000013",
#                     "oldCode": "205"
#                 },
#                 {
#                     "id": "CXVId",
#                     "label": "Hampshire",
#                     "code": "E10000014",
#                     "oldCode": "850"
#                 },
#                 {
#                     "id": "yW5aB",
#                     "label": "Haringey",
#                     "code": "E09000014",
#                     "oldCode": "309"
#                 },
#                 {
#                     "id": "RySka",
#                     "label": "Harrow",
#                     "code": "E09000015",
#                     "oldCode": "310"
#                 },
#                 {
#                     "id": "dP0Zw",
#                     "label": "Hartlepool",
#                     "code": "E06000001",
#                     "oldCode": "805"
#                 },
#                 {
#                     "id": "bqZtT",
#                     "label": "Havering",
#                     "code": "E09000016",
#                     "oldCode": "311"
#                 },
#                 {
#                     "id": "y2daB",
#                     "label": "Herefordshire, County of",
#                     "code": "E06000019",
#                     "oldCode": "884"
#                 },
#                 {
#                     "id": "YJuHK",
#                     "label": "Hertfordshire",
#                     "code": "E10000015",
#                     "oldCode": "919"
#                 },
#                 {
#                     "id": "Db3Qe",
#                     "label": "Hillingdon",
#                     "code": "E09000017",
#                     "oldCode": "312"
#                 },
#                 {
#                     "id": "emJuS",
#                     "label": "Hounslow",
#                     "code": "E09000018",
#                     "oldCode": "313"
#                 },
#                 {
#                     "id": "b8tTc",
#                     "label": "Isle of Wight",
#                     "code": "E06000046",
#                     "oldCode": "921"
#                 },
#                 {
#                     "id": "NKsDC",
#                     "label": "Isles of Scilly",
#                     "code": "E06000053",
#                     "oldCode": "420"
#                 },
#                 {
#                     "id": "5TYdi",
#                     "label": "Islington",
#                     "code": "E09000019",
#                     "oldCode": "206"
#                 },
#                 {
#                     "id": "4kdUZ",
#                     "label": "Kensington and Chelsea",
#                     "code": "E09000020",
#                     "oldCode": "207"
#                 },
#                 {
#                     "id": "qgvjG",
#                     "label": "Kent",
#                     "code": "E10000016",
#                     "oldCode": "886"
#                 },
#                 {
#                     "id": "S0OVx",
#                     "label": "Kingston upon Hull, City of",
#                     "code": "E06000010",
#                     "oldCode": "810"
#                 },
#                 {
#                     "id": "mU59K",
#                     "label": "Kingston upon Thames",
#                     "code": "E09000021",
#                     "oldCode": "314"
#                 },
#                 {
#                     "id": "TuNPJ",
#                     "label": "Kirklees",
#                     "code": "E08000034",
#                     "oldCode": "382"
#                 },
#                 {
#                     "id": "IXFBz",
#                     "label": "Knowsley",
#                     "code": "E08000011",
#                     "oldCode": "340"
#                 },
#                 {
#                     "id": "0evT5",
#                     "label": "Lambeth",
#                     "code": "E09000022",
#                     "oldCode": "208"
#                 },
#                 {
#                     "id": "alDLP",
#                     "label": "Lancashire",
#                     "code": "E10000017",
#                     "oldCode": "888"
#                 },
#                 {
#                     "id": "hLOyW",
#                     "label": "Leeds",
#                     "code": "E08000035",
#                     "oldCode": "383"
#                 },
#                 {
#                     "id": "z4FQE",
#                     "label": "Leicester",
#                     "code": "E06000016",
#                     "oldCode": "856"
#                 },
#                 {
#                     "id": "BYe7J",
#                     "label": "Leicestershire",
#                     "code": "E10000018",
#                     "oldCode": "855"
#                 },
#                 {
#                     "id": "WcR2b",
#                     "label": "Lewisham",
#                     "code": "E09000023",
#                     "oldCode": "209"
#                 },
#                 {
#                     "id": "znRFQ",
#                     "label": "Lincolnshire",
#                     "code": "E10000019",
#                     "oldCode": "925"
#                 },
#                 {
#                     "id": "iNE6X",
#                     "label": "Liverpool",
#                     "code": "E08000012",
#                     "oldCode": "341"
#                 },
#                 {
#                     "id": "VN5XE",
#                     "label": "Luton",
#                     "code": "E06000032",
#                     "oldCode": "821"
#                 },
#                 {
#                     "id": "NrDCj",
#                     "label": "Manchester",
#                     "code": "E08000003",
#                     "oldCode": "352"
#                 },
#                 {
#                     "id": "dt0Zw",
#                     "label": "Medway",
#                     "code": "E06000035",
#                     "oldCode": "887"
#                 },
#                 {
#                     "id": "EADqF",
#                     "label": "Merton",
#                     "code": "E09000024",
#                     "oldCode": "315"
#                 },
#                 {
#                     "id": "O7CLF",
#                     "label": "Middlesbrough",
#                     "code": "E06000002",
#                     "oldCode": "806"
#                 },
#                 {
#                     "id": "3P8uH",
#                     "label": "Milton Keynes",
#                     "code": "E06000042",
#                     "oldCode": "826"
#                 },
#                 {
#                     "id": "a2NLP",
#                     "label": "Newcastle upon Tyne",
#                     "code": "E08000021",
#                     "oldCode": "391"
#                 },
#                 {
#                     "id": "Qt6wb",
#                     "label": "Newham",
#                     "code": "E09000025",
#                     "oldCode": "316"
#                 },
#                 {
#                     "id": "kLDhs",
#                     "label": "Norfolk",
#                     "code": "E10000020",
#                     "oldCode": "926"
#                 },
#                 {
#                     "id": "YPHKM",
#                     "label": "North East Lincolnshire",
#                     "code": "E06000012",
#                     "oldCode": "812"
#                 },
#                 {
#                     "id": "qFjG7",
#                     "label": "North Lincolnshire",
#                     "code": "E06000013",
#                     "oldCode": "813"
#                 },
#                 {
#                     "id": "5PHdi",
#                     "label": "North Northamptonshire",
#                     "code": "E06000061",
#                     "oldCode": "940"
#                 },
#                 {
#                     "id": "fyYFZ",
#                     "label": "North Somerset",
#                     "code": "E06000024",
#                     "oldCode": "802"
#                 },
#                 {
#                     "id": "BfP7J",
#                     "label": "North Tyneside",
#                     "code": "E08000022",
#                     "oldCode": "392"
#                 },
#                 {
#                     "id": "o0dmX",
#                     "label": "North Yorkshire",
#                     "code": "E06000065",
#                     "oldCode": "815"
#                 },
#                 {
#                     "id": "9e4vZ",
#                     "label": "Northumberland",
#                     "code": "E06000057",
#                     "oldCode": "929"
#                 },
#                 {
#                     "id": "uxo41",
#                     "label": "Nottingham",
#                     "code": "E06000018",
#                     "oldCode": "892"
#                 },
#                 {
#                     "id": "ToMPJ",
#                     "label": "Nottinghamshire",
#                     "code": "E10000024",
#                     "oldCode": "891"
#                 },
#                 {
#                     "id": "wwbxT",
#                     "label": "Oldham",
#                     "code": "E08000004",
#                     "oldCode": "353"
#                 },
#                 {
#                     "id": "csC31",
#                     "label": "Oxfordshire",
#                     "code": "E10000025",
#                     "oldCode": "931"
#                 },
#                 {
#                     "id": "AkGK0",
#                     "label": "Peterborough",
#                     "code": "E06000031",
#                     "oldCode": "874"
#                 },
#                 {
#                     "id": "eNuSW",
#                     "label": "Plymouth",
#                     "code": "E06000026",
#                     "oldCode": "879"
#                 },
#                 {
#                     "id": "yVaBm",
#                     "label": "Portsmouth",
#                     "code": "E06000044",
#                     "oldCode": "851"
#                 },
#                 {
#                     "id": "UfRFO",
#                     "label": "Reading",
#                     "code": "E06000038",
#                     "oldCode": "870"
#                 },
#                 {
#                     "id": "9Ru4v",
#                     "label": "Redbridge",
#                     "code": "E09000026",
#                     "oldCode": "317"
#                 },
#                 {
#                     "id": "7zXob",
#                     "label": "Redcar and Cleveland",
#                     "code": "E06000003",
#                     "oldCode": "807"
#                 },
#                 {
#                     "id": "23Llz",
#                     "label": "Richmond upon Thames",
#                     "code": "E09000027",
#                     "oldCode": "318"
#                 },
#                 {
#                     "id": "o49mX",
#                     "label": "Rochdale",
#                     "code": "E08000005",
#                     "oldCode": "354"
#                 },
#                 {
#                     "id": "YFeHK",
#                     "label": "Rotherham",
#                     "code": "E08000018",
#                     "oldCode": "372"
#                 },
#                 {
#                     "id": "krhsL",
#                     "label": "Rutland",
#                     "code": "E06000017",
#                     "oldCode": "857"
#                 },
#                 {
#                     "id": "9RR4v",
#                     "label": "Salford",
#                     "code": "E08000006",
#                     "oldCode": "355"
#                 },
#                 {
#                     "id": "cZO31",
#                     "label": "Sandwell",
#                     "code": "E08000028",
#                     "oldCode": "333"
#                 },
#                 {
#                     "id": "6DArf",
#                     "label": "Sefton",
#                     "code": "E08000014",
#                     "oldCode": "343"
#                 },
#                 {
#                     "id": "qGJjG",
#                     "label": "Sheffield",
#                     "code": "E08000019",
#                     "oldCode": "373"
#                 },
#                 {
#                     "id": "45UZU",
#                     "label": "Shropshire",
#                     "code": "E06000051",
#                     "oldCode": "893"
#                 },
#                 {
#                     "id": "oBmXk",
#                     "label": "Slough",
#                     "code": "E06000039",
#                     "oldCode": "871"
#                 },
#                 {
#                     "id": "5Tsdi",
#                     "label": "Solihull",
#                     "code": "E08000029",
#                     "oldCode": "334"
#                 },
#                 {
#                     "id": "9PP4v",
#                     "label": "Somerset",
#                     "code": "E06000066",
#                     "oldCode": "933"
#                 },
#                 {
#                     "id": "juAMt",
#                     "label": "South Gloucestershire",
#                     "code": "E06000025",
#                     "oldCode": "803"
#                 },
#                 {
#                     "id": "zvUFQ",
#                     "label": "South Tyneside",
#                     "code": "E08000023",
#                     "oldCode": "393"
#                 },
#                 {
#                     "id": "Rpka2",
#                     "label": "Southampton",
#                     "code": "E06000045",
#                     "oldCode": "852"
#                 },
#                 {
#                     "id": "PEebW",
#                     "label": "Southend-on-Sea",
#                     "code": "E06000033",
#                     "oldCode": "882"
#                 },
#                 {
#                     "id": "PoTeb",
#                     "label": "Southwark",
#                     "code": "E09000028",
#                     "oldCode": "210"
#                 },
#                 {
#                     "id": "LlMWj",
#                     "label": "St. Helens",
#                     "code": "E08000013",
#                     "oldCode": "342"
#                 },
#                 {
#                     "id": "tATEm",
#                     "label": "Staffordshire",
#                     "code": "E10000028",
#                     "oldCode": "860"
#                 },
#                 {
#                     "id": "dPe0Z",
#                     "label": "Stockport",
#                     "code": "E08000007",
#                     "oldCode": "356"
#                 },
#                 {
#                     "id": "pTSoj",
#                     "label": "Stockton-on-Tees",
#                     "code": "E06000004",
#                     "oldCode": "808"
#                 },
#                 {
#                     "id": "cg31S",
#                     "label": "Stoke-on-Trent",
#                     "code": "E06000021",
#                     "oldCode": "861"
#                 },
#                 {
#                     "id": "fFLYF",
#                     "label": "Suffolk",
#                     "code": "E10000029",
#                     "oldCode": "935"
#                 },
#                 {
#                     "id": "kaNhs",
#                     "label": "Sunderland",
#                     "code": "E08000024",
#                     "oldCode": "394"
#                 },
#                 {
#                     "id": "jOmAM",
#                     "label": "Surrey",
#                     "code": "E10000030",
#                     "oldCode": "936"
#                 },
#                 {
#                     "id": "NwNDC",
#                     "label": "Sutton",
#                     "code": "E09000029",
#                     "oldCode": "319"
#                 },
#                 {
#                     "id": "ghO9G",
#                     "label": "Swindon",
#                     "code": "E06000030",
#                     "oldCode": "866"
#                 },
#                 {
#                     "id": "OBXCL",
#                     "label": "Tameside",
#                     "code": "E08000008",
#                     "oldCode": "357"
#                 },
#                 {
#                     "id": "TsPJP",
#                     "label": "Telford and Wrekin",
#                     "code": "E06000020",
#                     "oldCode": "894"
#                 },
#                 {
#                     "id": "1Ti3Z",
#                     "label": "Thurrock",
#                     "code": "E06000034",
#                     "oldCode": "883"
#                 },
#                 {
#                     "id": "TrPJP",
#                     "label": "Torbay",
#                     "code": "E06000027",
#                     "oldCode": "880"
#                 },
#                 {
#                     "id": "wqtbx",
#                     "label": "Tower Hamlets",
#                     "code": "E09000030",
#                     "oldCode": "211"
#                 },
#                 {
#                     "id": "7YFXo",
#                     "label": "Trafford",
#                     "code": "E08000009",
#                     "oldCode": "358"
#                 },
#                 {
#                     "id": "mUq9K",
#                     "label": "Wakefield",
#                     "code": "E08000036",
#                     "oldCode": "384"
#                 },
#                 {
#                     "id": "tj0Em",
#                     "label": "Walsall",
#                     "code": "E08000030",
#                     "oldCode": "335"
#                 },
#                 {
#                     "id": "oU4mX",
#                     "label": "Waltham Forest",
#                     "code": "E09000031",
#                     "oldCode": "320"
#                 },
#                 {
#                     "id": "9kk4v",
#                     "label": "Wandsworth",
#                     "code": "E09000032",
#                     "oldCode": "212"
#                 },
#                 {
#                     "id": "LxWjE",
#                     "label": "Warrington",
#                     "code": "E06000007",
#                     "oldCode": "877"
#                 },
#                 {
#                     "id": "e9QuS",
#                     "label": "Warwickshire",
#                     "code": "E10000031",
#                     "oldCode": "937"
#                 },
#                 {
#                     "id": "lpcBn",
#                     "label": "West Berkshire",
#                     "code": "E06000037",
#                     "oldCode": "869"
#                 },
#                 {
#                     "id": "4h0UZ",
#                     "label": "West Northamptonshire",
#                     "code": "E06000062",
#                     "oldCode": "941"
#                 },
#                 {
#                     "id": "ToDPJ",
#                     "label": "West Sussex",
#                     "code": "E10000032",
#                     "oldCode": "938"
#                 },
#                 {
#                     "id": "deu0Z",
#                     "label": "Westminster",
#                     "code": "E09000033",
#                     "oldCode": "213"
#                 },
#                 {
#                     "id": "0unT5",
#                     "label": "Westmorland and Furness",
#                     "code": "E06000064",
#                     "oldCode": "943"
#                 },
#                 {
#                     "id": "p5PSo",
#                     "label": "Wigan",
#                     "code": "E08000010",
#                     "oldCode": "359"
#                 },
#                 {
#                     "id": "WU2bo",
#                     "label": "Wiltshire",
#                     "code": "E06000054",
#                     "oldCode": "865"
#                 },
#                 {
#                     "id": "rRNj1",
#                     "label": "Windsor and Maidenhead",
#                     "code": "E06000040",
#                     "oldCode": "868"
#                 },
#                 {
#                     "id": "0ehT5",
#                     "label": "Wirral",
#                     "code": "E08000015",
#                     "oldCode": "344"
#                 },
#                 {
#                     "id": "GZgru",
#                     "label": "Wokingham",
#                     "code": "E06000041",
#                     "oldCode": "872"
#                 },
#                 {
#                     "id": "fzaYF",
#                     "label": "Wolverhampton",
#                     "code": "E08000031",
#                     "oldCode": "336"
#                 },
#                 {
#                     "id": "hWCyW",
#                     "label": "Worcestershire",
#                     "code": "E10000034",
#                     "oldCode": "885"
#                 },
#                 {
#                     "id": "arLPb",
#                     "label": "York",
#                     "code": "E06000014",
#                     "oldCode": "816"
#                 }
#             ]
#         },
#         {
#             "level": {
#                 "code": "NAT",
#                 "label": "National"
#             },
#             "options": [
#                 {
#                     "id": "mRj9K",
#                     "label": "England",
#                     "code": "E92000001"
#                 }
#             ]
#         },
#         {
#             "level": {
#                 "code": "REG",
#                 "label": "Regional"
#             },
#             "options": [
#                 {
#                     "id": "Pmjeb",
#                     "label": "East Midlands",
#                     "code": "E12000004"
#                 },
#                 {
#                     "id": "deq0Z",
#                     "label": "East of England",
#                     "code": "E12000006"
#                 },
#                 {
#                     "id": "kxGhs",
#                     "label": "London",
#                     "code": "E12000007"
#                 },
#                 {
#                     "id": "gBaO9",
#                     "label": "North East",
#                     "code": "E12000001"
#                 },
#                 {
#                     "id": "ACyGK",
#                     "label": "North West",
#                     "code": "E12000002"
#                 },
#                 {
#                     "id": "u4Co4",
#                     "label": "South East",
#                     "code": "E12000008"
#                 },
#                 {
#                     "id": "lZVcB",
#                     "label": "South West",
#                     "code": "E12000009"
#                 },
#                 {
#                     "id": "1Nei3",
#                     "label": "West Midlands",
#                     "code": "E12000005"
#                 },
#                 {
#                     "id": "zecFQ",
#                     "label": "Yorkshire and The Humber",
#                     "code": "E12000003"
#                 }
#             ]
#         }
#     ],
#     "timePeriods": [
#         {
#             "code": "W1",
#             "period": "2024",
#             "label": "2024 Week 1"
#         },
#         {
#             "code": "W10",
#             "period": "2024",
#             "label": "2024 Week 10"
#         },
#         {
#             "code": "W11",
#             "period": "2024",
#             "label": "2024 Week 11"
#         },
#         {
#             "code": "W12",
#             "period": "2024",
#             "label": "2024 Week 12"
#         },
#         {
#             "code": "W13",
#             "period": "2024",
#             "label": "2024 Week 13"
#         },
#         {
#             "code": "W15",
#             "period": "2024",
#             "label": "2024 Week 15"
#         },
#         {
#             "code": "W16",
#             "period": "2024",
#             "label": "2024 Week 16"
#         },
#         {
#             "code": "W17",
#             "period": "2024",
#             "label": "2024 Week 17"
#         },
#         {
#             "code": "W18",
#             "period": "2024",
#             "label": "2024 Week 18"
#         },
#         {
#             "code": "W19",
#             "period": "2024",
#             "label": "2024 Week 19"
#         },
#         {
#             "code": "W2",
#             "period": "2024",
#             "label": "2024 Week 2"
#         },
#         {
#             "code": "W20",
#             "period": "2024",
#             "label": "2024 Week 20"
#         },
#         {
#             "code": "W21",
#             "period": "2024",
#             "label": "2024 Week 21"
#         },
#         {
#             "code": "W23",
#             "period": "2024",
#             "label": "2024 Week 23"
#         },
#         {
#             "code": "W24",
#             "period": "2024",
#             "label": "2024 Week 24"
#         },
#         {
#             "code": "W25",
#             "period": "2024",
#             "label": "2024 Week 25"
#         },
#         {
#             "code": "W3",
#             "period": "2024",
#             "label": "2024 Week 3"
#         },
#         {
#             "code": "W37",
#             "period": "2023",
#             "label": "2023 Week 37"
#         },
#         {
#             "code": "W38",
#             "period": "2023",
#             "label": "2023 Week 38"
#         },
#         {
#             "code": "W39",
#             "period": "2023",
#             "label": "2023 Week 39"
#         },
#         {
#             "code": "W4",
#             "period": "2024",
#             "label": "2024 Week 4"
#         },
#         {
#             "code": "W40",
#             "period": "2023",
#             "label": "2023 Week 40"
#         },
#         {
#             "code": "W41",
#             "period": "2023",
#             "label": "2023 Week 41"
#         },
#         {
#             "code": "W42",
#             "period": "2023",
#             "label": "2023 Week 42"
#         },
#         {
#             "code": "W43",
#             "period": "2023",
#             "label": "2023 Week 43"
#         },
#         {
#             "code": "W44",
#             "period": "2023",
#             "label": "2023 Week 44"
#         },
#         {
#             "code": "W45",
#             "period": "2023",
#             "label": "2023 Week 45"
#         },
#         {
#             "code": "W46",
#             "period": "2023",
#             "label": "2023 Week 46"
#         },
#         {
#             "code": "W47",
#             "period": "2023",
#             "label": "2023 Week 47"
#         },
#         {
#             "code": "W48",
#             "period": "2023",
#             "label": "2023 Week 48"
#         },
#         {
#             "code": "W49",
#             "period": "2023",
#             "label": "2023 Week 49"
#         },
#         {
#             "code": "W5",
#             "period": "2024",
#             "label": "2024 Week 5"
#         },
#         {
#             "code": "W50",
#             "period": "2023",
#             "label": "2023 Week 50"
#         },
#         {
#             "code": "W51",
#             "period": "2023",
#             "label": "2023 Week 51"
#         },
#         {
#             "code": "W6",
#             "period": "2024",
#             "label": "2024 Week 6"
#         },
#         {
#             "code": "W7",
#             "period": "2024",
#             "label": "2024 Week 7"
#         },
#         {
#             "code": "W8",
#             "period": "2024",
#             "label": "2024 Week 8"
#         },
#         {
#             "code": "W9",
#             "period": "2024",
#             "label": "2024 Week 9"
#         }
#     ]
# }

# %% [markdown]
# ### Example Query

# %%
data = {
    "indicators": ["tj0Em", "fzaYF", "jgoAM"]
}
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 20, Finished, Available, Finished)

# %%
SetB.post_data_set_query(data)
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 21, Finished, Available, Finished)
# Retrived page 1 of 3316.
# Retrived page 2 of 3316.
# Retrived page 3 of 3316.
# Retrived page 4 of 3316.
# Retrived page 5 of 3316.
# Retrived page 6 of 3316.
# Retrived page 7 of 3316.
# Retrived page 8 of 3316.
# Retrived page 9 of 3316.
# Retrived page 10 of 3316.
# Retrived page 11 of 3316.
# Retrived page 12 of 3316.
# Retrived page 13 of 3316.
# Retrived page 14 of 3316.
# Retrived page 15 of 3316.
# Retrived page 16 of 3316.
# Retrived page 17 of 3316.
# Retrived page 18 of 3316.
# Retrived page 19 of 3316.
# Retrived page 20 of 3316.
# Retrived page 21 of 3316.
# Retrived page 22 of 3316.
# Retrived page 23 of 3316.
# Retrived page 24 of 3316.
# Retrived page 25 of 3316.
# Retrived page 26 of 3316.
# Retrived page 27 of 3316.
# Retrived page 28 of 3316.
# Retrived page 29 of 3316.
# Retrived page 30 of 3316.
# Retrived page 31 of 3316.
# Retrived page 32 of 3316.
# Retrived page 33 of 3316.
# Retrived page 34 of 3316.
# Retrived page 35 of 3316.
# Retrived page 36 of 3316.
# Retrived page 37 of 3316.
# Retrived page 38 of 3316.
# Retrived page 39 of 3316.
# Retrived page 40 of 3316.
# Retrived page 41 of 3316.
# Retrived page 42 of 3316.
# Retrived page 43 of 3316.
# Retrived page 44 of 3316.
# Retrived page 45 of 3316.
# Retrived page 46 of 3316.
# Retrived page 47 of 3316.
# Retrived page 48 of 3316.
# Retrived page 49 of 3316.
# Retrived page 50 of 3316.
# Retrived page 51 of 3316.
# Retrived page 52 of 3316.
# Retrived page 53 of 3316.
# Retrived page 54 of 3316.
# Retrived page 55 of 3316.
# Retrived page 56 of 3316.
# Retrived page 57 of 3316.
# Retrived page 58 of 3316.
# Retrived page 59 of 3316.
# Retrived page 60 of 3316.
# Retrived page 61 of 3316.
# Retrived page 62 of 3316.
# Retrived page 63 of 3316.
# Retrived page 64 of 3316.
# Retrived page 65 of 3316.
# Retrived page 66 of 3316.
# Retrived page 67 of 3316.
# Retrived page 68 of 3316.
# Retrived page 69 of 3316.
# Retrived page 70 of 3316.
# Retrived page 71 of 3316.
# Retrived page 72 of 3316.
# Retrived page 73 of 3316.
# Retrived page 74 of 3316.
# Retrived page 75 of 3316.
# Retrived page 76 of 3316.
# Retrived page 77 of 3316.
# Retrived page 78 of 3316.
# Retrived page 79 of 3316.
# Retrived page 80 of 3316.
# Retrived page 81 of 3316.
# Retrived page 82 of 3316.
# Retrived page 83 of 3316.
# Retrived page 84 of 3316.
# Retrived page 85 of 3316.
# Retrived page 86 of 3316.
# Retrived page 87 of 3316.
# Retrived page 88 of 3316.
# Retrived page 89 of 3316.
# Retrived page 90 of 3316.
# Retrived page 91 of 3316.
# Retrived page 92 of 3316.
# Retrived page 93 of 3316.
# Retrived page 94 of 3316.
# Retrived page 95 of 3316.
# Retrived page 96 of 3316.
# Retrived page 97 of 3316.
# Retrived page 98 of 3316.
# Retrived page 99 of 3316.
# Retrived page 100 of 3316.
# Retrived page 101 of 3316.
# Retrived page 102 of 3316.
# Retrived page 103 of 3316.
# Retrived page 104 of 3316.
# Retrived page 105 of 3316.
# Retrived page 106 of 3316.
# Retrived page 107 of 3316.
# Retrived page 108 of 3316.
# Retrived page 109 of 3316.
# Retrived page 110 of 3316.
# Retrived page 111 of 3316.
# Retrived page 112 of 3316.
# Retrived page 113 of 3316.
# Retrived page 114 of 3316.
# Retrived page 115 of 3316.
# Retrived page 116 of 3316.
# Retrived page 117 of 3316.
# Retrived page 118 of 3316.
# Retrived page 119 of 3316.
# Retrived page 120 of 3316.
# Retrived page 121 of 3316.
# Retrived page 122 of 3316.
# Retrived page 123 of 3316.
# Retrived page 124 of 3316.
# Retrived page 125 of 3316.
# Retrived page 126 of 3316.
# Retrived page 127 of 3316.
# Retrived page 128 of 3316.
# Retrived page 129 of 3316.
# Retrived page 130 of 3316.
# Retrived page 131 of 3316.
# Retrived page 132 of 3316.
# Retrived page 133 of 3316.
# Retrived page 134 of 3316.
# Retrived page 135 of 3316.
# Retrived page 136 of 3316.
# Retrived page 137 of 3316.
# Retrived page 138 of 3316.
# Retrived page 139 of 3316.
# Retrived page 140 of 3316.
# Retrived page 141 of 3316.
# Retrived page 142 of 3316.
# Retrived page 143 of 3316.
# Retrived page 144 of 3316.
# Retrived page 145 of 3316.
# Retrived page 146 of 3316.
# Retrived page 147 of 3316.
# Retrived page 148 of 3316.
# Retrived page 149 of 3316.
# Retrived page 150 of 3316.
# Retrived page 151 of 3316.
# Retrived page 152 of 3316.
# Retrived page 153 of 3316.
# Retrived page 154 of 3316.
# Retrived page 155 of 3316.
# Retrived page 156 of 3316.
# Retrived page 157 of 3316.
# Retrived page 158 of 3316.
# Retrived page 159 of 3316.
# Retrived page 160 of 3316.
# Retrived page 161 of 3316.
# Retrived page 162 of 3316.
# Retrived page 163 of 3316.
# Retrived page 164 of 3316.
# Retrived page 165 of 3316.
# Retrived page 166 of 3316.
# Retrived page 167 of 3316.
# Retrived page 168 of 3316.
# Retrived page 169 of 3316.
# Retrived page 170 of 3316.
# Retrived page 171 of 3316.
# Retrived page 172 of 3316.
# Retrived page 173 of 3316.
# Retrived page 174 of 3316.
# Retrived page 175 of 3316.
# Retrived page 176 of 3316.
# Retrived page 177 of 3316.
# Retrived page 178 of 3316.
# Retrived page 179 of 3316.
# Retrived page 180 of 3316.
# Retrived page 181 of 3316.
# Retrived page 182 of 3316.
# Retrived page 183 of 3316.
# Retrived page 184 of 3316.
# Retrived page 185 of 3316.
# Retrived page 186 of 3316.
# Retrived page 187 of 3316.
# Retrived page 188 of 3316.
# Retrived page 189 of 3316.
# Retrived page 190 of 3316.
# Retrived page 191 of 3316.
# Retrived page 192 of 3316.
# Retrived page 193 of 3316.
# Retrived page 194 of 3316.
# Retrived page 195 of 3316.
# Retrived page 196 of 3316.
# Retrived page 197 of 3316.
# Retrived page 198 of 3316.
# Retrived page 199 of 3316.
# Retrived page 200 of 3316.
# Retrived page 201 of 3316.
# Retrived page 202 of 3316.
# Retrived page 203 of 3316.
# Retrived page 204 of 3316.
# Retrived page 205 of 3316.
# Retrived page 206 of 3316.
# Retrived page 207 of 3316.
# Retrived page 208 of 3316.
# Retrived page 209 of 3316.
# Retrived page 210 of 3316.
# Retrived page 211 of 3316.
# Retrived page 212 of 3316.
# Retrived page 213 of 3316.
# Retrived page 214 of 3316.
# Retrived page 215 of 3316.
# Retrived page 216 of 3316.
# Retrived page 217 of 3316.
# Retrived page 218 of 3316.
# Retrived page 219 of 3316.
# Retrived page 220 of 3316.
# Retrived page 221 of 3316.
# Retrived page 222 of 3316.
# Retrived page 223 of 3316.
# Retrived page 224 of 3316.
# Retrived page 225 of 3316.
# Retrived page 226 of 3316.
# Retrived page 227 of 3316.
# Retrived page 228 of 3316.
# Retrived page 229 of 3316.
# Retrived page 230 of 3316.
# Retrived page 231 of 3316.
# Retrived page 232 of 3316.
# Retrived page 233 of 3316.
# Retrived page 234 of 3316.
# Retrived page 235 of 3316.
# Retrived page 236 of 3316.
# Retrived page 237 of 3316.
# Retrived page 238 of 3316.
# Retrived page 239 of 3316.
# Retrived page 240 of 3316.
# Retrived page 241 of 3316.
# Retrived page 242 of 3316.
# Retrived page 243 of 3316.
# Retrived page 244 of 3316.
# Retrived page 245 of 3316.
# Retrived page 246 of 3316.
# Retrived page 247 of 3316.
# Retrived page 248 of 3316.
# Retrived page 249 of 3316.
# Retrived page 250 of 3316.
# Retrived page 251 of 3316.
# Retrived page 252 of 3316.
# Retrived page 253 of 3316.
# Retrived page 254 of 3316.
# Retrived page 255 of 3316.
# Retrived page 256 of 3316.
# Retrived page 257 of 3316.
# Retrived page 258 of 3316.
# Retrived page 259 of 3316.
# Retrived page 260 of 3316.
# Retrived page 261 of 3316.
# Retrived page 262 of 3316.
# Retrived page 263 of 3316.
# Retrived page 264 of 3316.
# Retrived page 265 of 3316.
# Retrived page 266 of 3316.
# Retrived page 267 of 3316.
# Retrived page 268 of 3316.
# Retrived page 269 of 3316.
# Retrived page 270 of 3316.
# Retrived page 271 of 3316.
# Retrived page 272 of 3316.
# Retrived page 273 of 3316.
# Retrived page 274 of 3316.
# Retrived page 275 of 3316.
# Retrived page 276 of 3316.
# Retrived page 277 of 3316.
# Retrived page 278 of 3316.
# Retrived page 279 of 3316.
# Retrived page 280 of 3316.
# Retrived page 281 of 3316.
# Retrived page 282 of 3316.
# Retrived page 283 of 3316.
# Retrived page 284 of 3316.
# Retrived page 285 of 3316.
# Retrived page 286 of 3316.
# Retrived page 287 of 3316.
# Retrived page 288 of 3316.
# Retrived page 289 of 3316.
# Retrived page 290 of 3316.
# Retrived page 291 of 3316.
# Retrived page 292 of 3316.
# Retrived page 293 of 3316.
# Retrived page 294 of 3316.
# Retrived page 295 of 3316.
# Retrived page 296 of 3316.
# Retrived page 297 of 3316.
# Retrived page 298 of 3316.
# Retrived page 299 of 3316.
# Retrived page 300 of 3316.
# Retrived page 301 of 3316.
# Retrived page 302 of 3316.
# Retrived page 303 of 3316.
# Retrived page 304 of 3316.
# Retrived page 305 of 3316.
# Retrived page 306 of 3316.
# Retrived page 307 of 3316.
# Retrived page 308 of 3316.
# Retrived page 309 of 3316.
# Retrived page 310 of 3316.
# Retrived page 311 of 3316.
# Retrived page 312 of 3316.
# Retrived page 313 of 3316.
# Retrived page 314 of 3316.
# Retrived page 315 of 3316.
# Retrived page 316 of 3316.
# Retrived page 317 of 3316.
# Retrived page 318 of 3316.
# Retrived page 319 of 3316.
# Retrived page 320 of 3316.
# Retrived page 321 of 3316.
# Retrived page 322 of 3316.
# Retrived page 323 of 3316.
# Retrived page 324 of 3316.
# Retrived page 325 of 3316.
# Retrived page 326 of 3316.
# Retrived page 327 of 3316.
# Retrived page 328 of 3316.
# Retrived page 329 of 3316.
# Retrived page 330 of 3316.
# Retrived page 331 of 3316.
# Retrived page 332 of 3316.
# Retrived page 333 of 3316.
# Retrived page 334 of 3316.
# Retrived page 335 of 3316.
# Retrived page 336 of 3316.
# Retrived page 337 of 3316.
# Retrived page 338 of 3316.
# Retrived page 339 of 3316.
# Retrived page 340 of 3316.
# Retrived page 341 of 3316.
# Retrived page 342 of 3316.
# Retrived page 343 of 3316.
# Retrived page 344 of 3316.
# Retrived page 345 of 3316.
# Retrived page 346 of 3316.
# Retrived page 347 of 3316.
# Retrived page 348 of 3316.
# Retrived page 349 of 3316.
# Retrived page 350 of 3316.
# Retrived page 351 of 3316.
# Retrived page 352 of 3316.
# Retrived page 353 of 3316.
# Retrived page 354 of 3316.
# Retrived page 355 of 3316.
# Retrived page 356 of 3316.
# Retrived page 357 of 3316.
# Retrived page 358 of 3316.
# Retrived page 359 of 3316.
# Retrived page 360 of 3316.
# Retrived page 361 of 3316.
# Retrived page 362 of 3316.
# Retrived page 363 of 3316.
# Retrived page 364 of 3316.
# Retrived page 365 of 3316.
# Retrived page 366 of 3316.
# Retrived page 367 of 3316.
# Retrived page 368 of 3316.
# Retrived page 369 of 3316.
# Retrived page 370 of 3316.
# Retrived page 371 of 3316.
# Retrived page 372 of 3316.
# Retrived page 373 of 3316.
# Retrived page 374 of 3316.
# Retrived page 375 of 3316.
# Retrived page 376 of 3316.
# Retrived page 377 of 3316.
# Retrived page 378 of 3316.
# Retrived page 379 of 3316.
# Retrived page 380 of 3316.
# Retrived page 381 of 3316.
# Retrived page 382 of 3316.
# Retrived page 383 of 3316.
# Retrived page 384 of 3316.
# Retrived page 385 of 3316.
# Retrived page 386 of 3316.
# Retrived page 387 of 3316.
# Retrived page 388 of 3316.
# Retrived page 389 of 3316.
# Retrived page 390 of 3316.
# Retrived page 391 of 3316.
# Retrived page 392 of 3316.
# Retrived page 393 of 3316.
# Retrived page 394 of 3316.
# Retrived page 395 of 3316.
# Retrived page 396 of 3316.
# Retrived page 397 of 3316.
# Retrived page 398 of 3316.
# Retrived page 399 of 3316.
# Retrived page 400 of 3316.
# Retrived page 401 of 3316.
# Retrived page 402 of 3316.
# Retrived page 403 of 3316.
# Retrived page 404 of 3316.
# Retrived page 405 of 3316.
# Retrived page 406 of 3316.
# Retrived page 407 of 3316.
# Retrived page 408 of 3316.
# Retrived page 409 of 3316.
# Retrived page 410 of 3316.
# Retrived page 411 of 3316.
# Retrived page 412 of 3316.
# Retrived page 413 of 3316.
# Retrived page 414 of 3316.
# Retrived page 415 of 3316.
# Retrived page 416 of 3316.
# Retrived page 417 of 3316.
# Retrived page 418 of 3316.
# Retrived page 419 of 3316.
# Retrived page 420 of 3316.
# Retrived page 421 of 3316.
# Retrived page 422 of 3316.
# Retrived page 423 of 3316.
# Retrived page 424 of 3316.
# Retrived page 425 of 3316.
# Retrived page 426 of 3316.
# Retrived page 427 of 3316.
# Retrived page 428 of 3316.
# Retrived page 429 of 3316.
# Retrived page 430 of 3316.
# Retrived page 431 of 3316.
# Retrived page 432 of 3316.
# Retrived page 433 of 3316.
# Retrived page 434 of 3316.
# Retrived page 435 of 3316.
# Retrived page 436 of 3316.
# Retrived page 437 of 3316.
# Retrived page 438 of 3316.
# Retrived page 439 of 3316.
# Retrived page 440 of 3316.
# Retrived page 441 of 3316.
# Retrived page 442 of 3316.
# Retrived page 443 of 3316.
# Retrived page 444 of 3316.
# Retrived page 445 of 3316.
# Retrived page 446 of 3316.
# Retrived page 447 of 3316.
# Retrived page 448 of 3316.
# Retrived page 449 of 3316.
# Retrived page 450 of 3316.
# Retrived page 451 of 3316.
# Retrived page 452 of 3316.
# Retrived page 453 of 3316.
# Retrived page 454 of 3316.
# Retrived page 455 of 3316.
# Retrived page 456 of 3316.
# Retrived page 457 of 3316.
# Retrived page 458 of 3316.
# Retrived page 459 of 3316.
# Retrived page 460 of 3316.
# Retrived page 461 of 3316.
# Retrived page 462 of 3316.
# Retrived page 463 of 3316.
# Retrived page 464 of 3316.
# Retrived page 465 of 3316.
# Retrived page 466 of 3316.
# Retrived page 467 of 3316.
# Retrived page 468 of 3316.
# Retrived page 469 of 3316.
# Retrived page 470 of 3316.
# Retrived page 471 of 3316.
# Retrived page 472 of 3316.
# Retrived page 473 of 3316.
# Retrived page 474 of 3316.
# Retrived page 475 of 3316.
# Retrived page 476 of 3316.
# Retrived page 477 of 3316.
# Retrived page 478 of 3316.
# Retrived page 479 of 3316.
# Retrived page 480 of 3316.
# Retrived page 481 of 3316.
# Retrived page 482 of 3316.
# Retrived page 483 of 3316.
# Retrived page 484 of 3316.
# Retrived page 485 of 3316.
# Retrived page 486 of 3316.
# Retrived page 487 of 3316.
# Retrived page 488 of 3316.
# Retrived page 489 of 3316.
# Retrived page 490 of 3316.
# Retrived page 491 of 3316.
# Retrived page 492 of 3316.
# Retrived page 493 of 3316.
# Retrived page 494 of 3316.
# Retrived page 495 of 3316.
# Retrived page 496 of 3316.
# Retrived page 497 of 3316.
# Retrived page 498 of 3316.
# Retrived page 499 of 3316.
# Retrived page 500 of 3316.
# Retrived page 501 of 3316.
# Retrived page 502 of 3316.
# Retrived page 503 of 3316.
# Retrived page 504 of 3316.
# Retrived page 505 of 3316.
# Retrived page 506 of 3316.
# Retrived page 507 of 3316.
# Retrived page 508 of 3316.
# Retrived page 509 of 3316.
# Retrived page 510 of 3316.
# Retrived page 511 of 3316.
# Retrived page 512 of 3316.
# Retrived page 513 of 3316.
# Retrived page 514 of 3316.
# Retrived page 515 of 3316.
# Retrived page 516 of 3316.
# Retrived page 517 of 3316.
# Retrived page 518 of 3316.
# Retrived page 519 of 3316.
# Retrived page 520 of 3316.
# Retrived page 521 of 3316.
# Retrived page 522 of 3316.
# Retrived page 523 of 3316.
# Retrived page 524 of 3316.
# Retrived page 525 of 3316.
# Retrived page 526 of 3316.
# Retrived page 527 of 3316.
# Retrived page 528 of 3316.
# Retrived page 529 of 3316.
# Retrived page 530 of 3316.
# Retrived page 531 of 3316.
# Retrived page 532 of 3316.
# Retrived page 533 of 3316.
# Retrived page 534 of 3316.
# Retrived page 535 of 3316.
# Retrived page 536 of 3316.
# Retrived page 537 of 3316.
# Retrived page 538 of 3316.
# Retrived page 539 of 3316.
# Retrived page 540 of 3316.
# Retrived page 541 of 3316.
# Retrived page 542 of 3316.
# Retrived page 543 of 3316.
# Retrived page 544 of 3316.
# Retrived page 545 of 3316.
# Retrived page 546 of 3316.
# Retrived page 547 of 3316.
# Retrived page 548 of 3316.
# Retrived page 549 of 3316.
# Retrived page 550 of 3316.
# Retrived page 551 of 3316.
# Retrived page 552 of 3316.
# Retrived page 553 of 3316.
# Retrived page 554 of 3316.
# Retrived page 555 of 3316.
# Retrived page 556 of 3316.
# Retrived page 557 of 3316.
# Retrived page 558 of 3316.
# Retrived page 559 of 3316.
# Retrived page 560 of 3316.
# Retrived page 561 of 3316.
# Retrived page 562 of 3316.
# Retrived page 563 of 3316.
# Retrived page 564 of 3316.
# Retrived page 565 of 3316.
# Retrived page 566 of 3316.
# Retrived page 567 of 3316.
# Retrived page 568 of 3316.
# Retrived page 569 of 3316.
# Retrived page 570 of 3316.
# Retrived page 571 of 3316.
# Retrived page 572 of 3316.
# Retrived page 573 of 3316.
# Retrived page 574 of 3316.
# Retrived page 575 of 3316.
# Retrived page 576 of 3316.
# Retrived page 577 of 3316.
# Retrived page 578 of 3316.
# Retrived page 579 of 3316.
# Retrived page 580 of 3316.
# Retrived page 581 of 3316.
# Retrived page 582 of 3316.
# Retrived page 583 of 3316.
# Retrived page 584 of 3316.
# Retrived page 585 of 3316.
# Retrived page 586 of 3316.
# Retrived page 587 of 3316.
# Retrived page 588 of 3316.
# Retrived page 589 of 3316.
# Retrived page 590 of 3316.
# Retrived page 591 of 3316.
# Retrived page 592 of 3316.
# Retrived page 593 of 3316.
# Retrived page 594 of 3316.
# Retrived page 595 of 3316.
# Retrived page 596 of 3316.
# Retrived page 597 of 3316.
# Retrived page 598 of 3316.
# Retrived page 599 of 3316.
# Retrived page 600 of 3316.
# Retrived page 601 of 3316.
# Retrived page 602 of 3316.
# Retrived page 603 of 3316.
# Retrived page 604 of 3316.
# Retrived page 605 of 3316.
# Retrived page 606 of 3316.
# Retrived page 607 of 3316.
# Retrived page 608 of 3316.
# Retrived page 609 of 3316.
# Retrived page 610 of 3316.
# Retrived page 611 of 3316.
# Retrived page 612 of 3316.
# Retrived page 613 of 3316.
# Retrived page 614 of 3316.
# Retrived page 615 of 3316.
# Retrived page 616 of 3316.
# Retrived page 617 of 3316.
# Retrived page 618 of 3316.
# Retrived page 619 of 3316.
# Retrived page 620 of 3316.
# Retrived page 621 of 3316.
# Retrived page 622 of 3316.
# Retrived page 623 of 3316.
# Retrived page 624 of 3316.
# Retrived page 625 of 3316.
# Retrived page 626 of 3316.
# Retrived page 627 of 3316.
# Retrived page 628 of 3316.
# Retrived page 629 of 3316.
# Retrived page 630 of 3316.
# Retrived page 631 of 3316.
# Retrived page 632 of 3316.
# Retrived page 633 of 3316.
# Retrived page 634 of 3316.
# Retrived page 635 of 3316.
# Retrived page 636 of 3316.
# Retrived page 637 of 3316.
# Retrived page 638 of 3316.
# Retrived page 639 of 3316.
# Retrived page 640 of 3316.
# Retrived page 641 of 3316.
# Retrived page 642 of 3316.
# Retrived page 643 of 3316.
# Retrived page 644 of 3316.
# Retrived page 645 of 3316.
# Retrived page 646 of 3316.
# Retrived page 647 of 3316.
# Retrived page 648 of 3316.
# Retrived page 649 of 3316.
# Retrived page 650 of 3316.
# Retrived page 651 of 3316.
# Retrived page 652 of 3316.
# Retrived page 653 of 3316.
# Retrived page 654 of 3316.
# Retrived page 655 of 3316.
# Retrived page 656 of 3316.
# Retrived page 657 of 3316.
# Retrived page 658 of 3316.
# Retrived page 659 of 3316.
# Retrived page 660 of 3316.
# Retrived page 661 of 3316.
# Retrived page 662 of 3316.
# Retrived page 663 of 3316.
# Retrived page 664 of 3316.
# Retrived page 665 of 3316.
# Retrived page 666 of 3316.
# Retrived page 667 of 3316.
# Retrived page 668 of 3316.
# Retrived page 669 of 3316.
# Retrived page 670 of 3316.
# Retrived page 671 of 3316.
# Retrived page 672 of 3316.
# Retrived page 673 of 3316.
# Retrived page 674 of 3316.
# Retrived page 675 of 3316.
# Retrived page 676 of 3316.
# Retrived page 677 of 3316.
# Retrived page 678 of 3316.
# Retrived page 679 of 3316.
# Retrived page 680 of 3316.
# Retrived page 681 of 3316.
# Retrived page 682 of 3316.
# Retrived page 683 of 3316.
# Retrived page 684 of 3316.
# Retrived page 685 of 3316.
# Retrived page 686 of 3316.
# Retrived page 687 of 3316.
# Retrived page 688 of 3316.
# Retrived page 689 of 3316.
# Retrived page 690 of 3316.
# Retrived page 691 of 3316.
# Retrived page 692 of 3316.
# Retrived page 693 of 3316.
# Retrived page 694 of 3316.
# Retrived page 695 of 3316.
# Retrived page 696 of 3316.
# Retrived page 697 of 3316.
# Retrived page 698 of 3316.
# Retrived page 699 of 3316.
# Retrived page 700 of 3316.
# Retrived page 701 of 3316.
# Retrived page 702 of 3316.
# Retrived page 703 of 3316.
# Retrived page 704 of 3316.
# Retrived page 705 of 3316.
# Retrived page 706 of 3316.
# Retrived page 707 of 3316.
# Retrived page 708 of 3316.
# Retrived page 709 of 3316.
# Retrived page 710 of 3316.
# Retrived page 711 of 3316.
# Retrived page 712 of 3316.
# Retrived page 713 of 3316.
# Retrived page 714 of 3316.
# Retrived page 715 of 3316.
# Retrived page 716 of 3316.
# Retrived page 717 of 3316.
# Retrived page 718 of 3316.
# Retrived page 719 of 3316.
# Retrived page 720 of 3316.
# Retrived page 721 of 3316.
# Retrived page 722 of 3316.
# Retrived page 723 of 3316.
# Retrived page 724 of 3316.
# Retrived page 725 of 3316.
# Retrived page 726 of 3316.
# Retrived page 727 of 3316.
# Retrived page 728 of 3316.
# Retrived page 729 of 3316.
# Retrived page 730 of 3316.
# Retrived page 731 of 3316.
# Retrived page 732 of 3316.
# Retrived page 733 of 3316.
# Retrived page 734 of 3316.
# Retrived page 735 of 3316.
# Retrived page 736 of 3316.
# Retrived page 737 of 3316.
# Retrived page 738 of 3316.
# Retrived page 739 of 3316.
# Retrived page 740 of 3316.
# Retrived page 741 of 3316.
# Retrived page 742 of 3316.
# Retrived page 743 of 3316.
# Retrived page 744 of 3316.
# Retrived page 745 of 3316.
# Retrived page 746 of 3316.
# Retrived page 747 of 3316.
# Retrived page 748 of 3316.
# Retrived page 749 of 3316.
# Retrived page 750 of 3316.
# Retrived page 751 of 3316.
# Retrived page 752 of 3316.
# Retrived page 753 of 3316.
# Retrived page 754 of 3316.
# Retrived page 755 of 3316.
# Retrived page 756 of 3316.
# Retrived page 757 of 3316.
# Retrived page 758 of 3316.
# Retrived page 759 of 3316.
# Retrived page 760 of 3316.
# Retrived page 761 of 3316.
# Retrived page 762 of 3316.
# Retrived page 763 of 3316.
# Retrived page 764 of 3316.
# Retrived page 765 of 3316.
# Retrived page 766 of 3316.
# Retrived page 767 of 3316.
# Retrived page 768 of 3316.
# Retrived page 769 of 3316.
# Retrived page 770 of 3316.
# Retrived page 771 of 3316.
# Retrived page 772 of 3316.
# Retrived page 773 of 3316.
# Retrived page 774 of 3316.
# Retrived page 775 of 3316.
# Retrived page 776 of 3316.
# Retrived page 777 of 3316.
# Retrived page 778 of 3316.
# Retrived page 779 of 3316.
# Retrived page 780 of 3316.
# Retrived page 781 of 3316.
# Retrived page 782 of 3316.
# Retrived page 783 of 3316.
# Retrived page 784 of 3316.
# Retrived page 785 of 3316.
# Retrived page 786 of 3316.
# Retrived page 787 of 3316.
# Retrived page 788 of 3316.
# Retrived page 789 of 3316.
# Retrived page 790 of 3316.
# Retrived page 791 of 3316.
# Retrived page 792 of 3316.
# Retrived page 793 of 3316.
# Retrived page 794 of 3316.
# Retrived page 795 of 3316.
# Retrived page 796 of 3316.
# Retrived page 797 of 3316.
# Retrived page 798 of 3316.
# Retrived page 799 of 3316.
# Retrived page 800 of 3316.
# Retrived page 801 of 3316.
# Retrived page 802 of 3316.
# Retrived page 803 of 3316.
# Retrived page 804 of 3316.
# Retrived page 805 of 3316.
# Retrived page 806 of 3316.
# Retrived page 807 of 3316.
# Retrived page 808 of 3316.
# Retrived page 809 of 3316.
# Retrived page 810 of 3316.
# Retrived page 811 of 3316.
# Retrived page 812 of 3316.
# Retrived page 813 of 3316.
# Retrived page 814 of 3316.
# Retrived page 815 of 3316.
# Retrived page 816 of 3316.
# Retrived page 817 of 3316.
# Retrived page 818 of 3316.
# Retrived page 819 of 3316.
# Retrived page 820 of 3316.
# Retrived page 821 of 3316.
# Retrived page 822 of 3316.
# Retrived page 823 of 3316.
# Retrived page 824 of 3316.
# Retrived page 825 of 3316.
# Retrived page 826 of 3316.
# Retrived page 827 of 3316.
# Retrived page 828 of 3316.
# Retrived page 829 of 3316.
# Retrived page 830 of 3316.
# Retrived page 831 of 3316.
# Retrived page 832 of 3316.
# Retrived page 833 of 3316.
# Retrived page 834 of 3316.
# Retrived page 835 of 3316.
# Retrived page 836 of 3316.
# Retrived page 837 of 3316.
# Retrived page 838 of 3316.
# Retrived page 839 of 3316.
# Retrived page 840 of 3316.
# Retrived page 841 of 3316.
# Retrived page 842 of 3316.
# Retrived page 843 of 3316.
# Retrived page 844 of 3316.
# Retrived page 845 of 3316.
# Retrived page 846 of 3316.
# Retrived page 847 of 3316.
# Retrived page 848 of 3316.
# Retrived page 849 of 3316.
# Retrived page 850 of 3316.
# Retrived page 851 of 3316.
# Retrived page 852 of 3316.
# Retrived page 853 of 3316.
# Retrived page 854 of 3316.
# Retrived page 855 of 3316.
# Retrived page 856 of 3316.
# Retrived page 857 of 3316.
# Retrived page 858 of 3316.
# Retrived page 859 of 3316.
# Retrived page 860 of 3316.
# Retrived page 861 of 3316.
# Retrived page 862 of 3316.
# Retrived page 863 of 3316.
# Retrived page 864 of 3316.
# Retrived page 865 of 3316.
# Retrived page 866 of 3316.
# Retrived page 867 of 3316.
# Retrived page 868 of 3316.
# Retrived page 869 of 3316.
# Retrived page 870 of 3316.
# Retrived page 871 of 3316.
# Retrived page 872 of 3316.
# Retrived page 873 of 3316.
# Retrived page 874 of 3316.
# Retrived page 875 of 3316.
# Retrived page 876 of 3316.
# Retrived page 877 of 3316.
# Retrived page 878 of 3316.
# Retrived page 879 of 3316.
# Retrived page 880 of 3316.
# Retrived page 881 of 3316.
# Retrived page 882 of 3316.
# Retrived page 883 of 3316.
# Retrived page 884 of 3316.
# Retrived page 885 of 3316.
# Retrived page 886 of 3316.
# Retrived page 887 of 3316.
# Retrived page 888 of 3316.
# Retrived page 889 of 3316.
# Retrived page 890 of 3316.
# Retrived page 891 of 3316.
# Retrived page 892 of 3316.
# Retrived page 893 of 3316.
# Retrived page 894 of 3316.
# Retrived page 895 of 3316.
# Retrived page 896 of 3316.
# Retrived page 897 of 3316.
# Retrived page 898 of 3316.
# Retrived page 899 of 3316.
# Retrived page 900 of 3316.
# Retrived page 901 of 3316.
# Retrived page 902 of 3316.
# Retrived page 903 of 3316.
# Retrived page 904 of 3316.
# Retrived page 905 of 3316.
# Retrived page 906 of 3316.
# Retrived page 907 of 3316.
# Retrived page 908 of 3316.
# Retrived page 909 of 3316.
# Retrived page 910 of 3316.
# Retrived page 911 of 3316.
# Retrived page 912 of 3316.
# Retrived page 913 of 3316.
# Retrived page 914 of 3316.
# Retrived page 915 of 3316.
# Retrived page 916 of 3316.
# Retrived page 917 of 3316.
# Retrived page 918 of 3316.
# Retrived page 919 of 3316.
# Retrived page 920 of 3316.
# Retrived page 921 of 3316.
# Retrived page 922 of 3316.
# Retrived page 923 of 3316.
# Retrived page 924 of 3316.
# Retrived page 925 of 3316.
# Retrived page 926 of 3316.
# Retrived page 927 of 3316.
# Retrived page 928 of 3316.
# Retrived page 929 of 3316.
# Retrived page 930 of 3316.
# Retrived page 931 of 3316.
# Retrived page 932 of 3316.
# Retrived page 933 of 3316.
# Retrived page 934 of 3316.
# Retrived page 935 of 3316.
# Retrived page 936 of 3316.
# Retrived page 937 of 3316.
# Retrived page 938 of 3316.
# Retrived page 939 of 3316.
# Retrived page 940 of 3316.
# Retrived page 941 of 3316.
# Retrived page 942 of 3316.
# Retrived page 943 of 3316.
# Retrived page 944 of 3316.
# Retrived page 945 of 3316.
# Retrived page 946 of 3316.
# Retrived page 947 of 3316.
# Retrived page 948 of 3316.
# Retrived page 949 of 3316.
# Retrived page 950 of 3316.
# Retrived page 951 of 3316.
# Retrived page 952 of 3316.
# Retrived page 953 of 3316.
# Retrived page 954 of 3316.
# Retrived page 955 of 3316.
# Retrived page 956 of 3316.
# Retrived page 957 of 3316.
# Retrived page 958 of 3316.
# Retrived page 959 of 3316.
# Retrived page 960 of 3316.
# Retrived page 961 of 3316.
# Retrived page 962 of 3316.
# Retrived page 963 of 3316.
# Retrived page 964 of 3316.
# Retrived page 965 of 3316.
# Retrived page 966 of 3316.
# Retrived page 967 of 3316.
# Retrived page 968 of 3316.
# Retrived page 969 of 3316.
# Retrived page 970 of 3316.
# Retrived page 971 of 3316.
# Retrived page 972 of 3316.
# Retrived page 973 of 3316.
# Retrived page 974 of 3316.
# Retrived page 975 of 3316.
# Retrived page 976 of 3316.
# Retrived page 977 of 3316.
# Retrived page 978 of 3316.
# Retrived page 979 of 3316.
# Retrived page 980 of 3316.
# Retrived page 981 of 3316.
# Retrived page 982 of 3316.
# Retrived page 983 of 3316.
# Retrived page 984 of 3316.
# Retrived page 985 of 3316.
# Retrived page 986 of 3316.
# Retrived page 987 of 3316.
# Retrived page 988 of 3316.
# Retrived page 989 of 3316.
# Retrived page 990 of 3316.
# Retrived page 991 of 3316.
# Retrived page 992 of 3316.
# Retrived page 993 of 3316.
# Retrived page 994 of 3316.
# Retrived page 995 of 3316.
# Retrived page 996 of 3316.
# Retrived page 997 of 3316.
# Retrived page 998 of 3316.
# Retrived page 999 of 3316.
# Retrived page 1000 of 3316.
# Retrived page 1001 of 3316.
# Retrived page 1002 of 3316.
# Retrived page 1003 of 3316.
# Retrived page 1004 of 3316.
# Retrived page 1005 of 3316.
# Retrived page 1006 of 3316.
# Retrived page 1007 of 3316.
# Retrived page 1008 of 3316.
# Retrived page 1009 of 3316.
# Retrived page 1010 of 3316.
# Retrived page 1011 of 3316.
# Retrived page 1012 of 3316.
# Retrived page 1013 of 3316.
# Retrived page 1014 of 3316.
# Retrived page 1015 of 3316.
# Retrived page 1016 of 3316.
# Retrived page 1017 of 3316.
# Retrived page 1018 of 3316.
# Retrived page 1019 of 3316.
# Retrived page 1020 of 3316.
# Retrived page 1021 of 3316.
# Retrived page 1022 of 3316.
# Retrived page 1023 of 3316.
# Retrived page 1024 of 3316.
# Retrived page 1025 of 3316.
# Retrived page 1026 of 3316.
# Retrived page 1027 of 3316.
# Retrived page 1028 of 3316.
# Retrived page 1029 of 3316.
# Retrived page 1030 of 3316.
# Retrived page 1031 of 3316.
# Retrived page 1032 of 3316.
# Retrived page 1033 of 3316.
# Retrived page 1034 of 3316.
# Retrived page 1035 of 3316.
# Retrived page 1036 of 3316.
# Retrived page 1037 of 3316.
# Retrived page 1038 of 3316.
# Retrived page 1039 of 3316.
# Retrived page 1040 of 3316.
# Retrived page 1041 of 3316.
# Retrived page 1042 of 3316.
# Retrived page 1043 of 3316.
# Retrived page 1044 of 3316.
# Retrived page 1045 of 3316.
# Retrived page 1046 of 3316.
# Retrived page 1047 of 3316.
# Retrived page 1048 of 3316.
# Retrived page 1049 of 3316.
# Retrived page 1050 of 3316.
# Retrived page 1051 of 3316.
# Retrived page 1052 of 3316.
# Retrived page 1053 of 3316.
# Retrived page 1054 of 3316.
# Retrived page 1055 of 3316.
# Retrived page 1056 of 3316.
# Retrived page 1057 of 3316.
# Retrived page 1058 of 3316.
# Retrived page 1059 of 3316.
# Retrived page 1060 of 3316.
# Retrived page 1061 of 3316.
# Retrived page 1062 of 3316.
# Retrived page 1063 of 3316.
# Retrived page 1064 of 3316.
# Retrived page 1065 of 3316.
# Retrived page 1066 of 3316.
# Retrived page 1067 of 3316.
# Retrived page 1068 of 3316.
# Retrived page 1069 of 3316.
# Retrived page 1070 of 3316.
# Retrived page 1071 of 3316.
# Retrived page 1072 of 3316.
# Retrived page 1073 of 3316.
# Retrived page 1074 of 3316.
# Retrived page 1075 of 3316.
# Retrived page 1076 of 3316.
# Retrived page 1077 of 3316.
# Retrived page 1078 of 3316.
# Retrived page 1079 of 3316.
# Retrived page 1080 of 3316.
# Retrived page 1081 of 3316.
# Retrived page 1082 of 3316.
# Retrived page 1083 of 3316.
# Retrived page 1084 of 3316.
# Retrived page 1085 of 3316.
# Retrived page 1086 of 3316.
# Retrived page 1087 of 3316.
# Retrived page 1088 of 3316.
# Retrived page 1089 of 3316.
# Retrived page 1090 of 3316.
# Retrived page 1091 of 3316.
# Retrived page 1092 of 3316.
# Retrived page 1093 of 3316.
# Retrived page 1094 of 3316.
# Retrived page 1095 of 3316.
# Retrived page 1096 of 3316.
# Retrived page 1097 of 3316.
# Retrived page 1098 of 3316.
# Retrived page 1099 of 3316.
# Retrived page 1100 of 3316.
# Retrived page 1101 of 3316.
# Retrived page 1102 of 3316.
# Retrived page 1103 of 3316.
# Retrived page 1104 of 3316.
# Retrived page 1105 of 3316.
# Retrived page 1106 of 3316.
# Retrived page 1107 of 3316.
# Retrived page 1108 of 3316.
# Retrived page 1109 of 3316.
# Retrived page 1110 of 3316.
# Retrived page 1111 of 3316.
# Retrived page 1112 of 3316.
# Retrived page 1113 of 3316.
# Retrived page 1114 of 3316.
# Retrived page 1115 of 3316.
# Retrived page 1116 of 3316.
# Retrived page 1117 of 3316.
# Retrived page 1118 of 3316.
# Retrived page 1119 of 3316.
# Retrived page 1120 of 3316.
# Retrived page 1121 of 3316.
# Retrived page 1122 of 3316.
# Retrived page 1123 of 3316.
# Retrived page 1124 of 3316.
# Retrived page 1125 of 3316.
# Retrived page 1126 of 3316.
# Retrived page 1127 of 3316.
# Retrived page 1128 of 3316.
# Retrived page 1129 of 3316.
# Retrived page 1130 of 3316.
# Retrived page 1131 of 3316.
# Retrived page 1132 of 3316.
# Retrived page 1133 of 3316.
# Retrived page 1134 of 3316.
# Retrived page 1135 of 3316.
# Retrived page 1136 of 3316.
# Retrived page 1137 of 3316.
# Retrived page 1138 of 3316.
# Retrived page 1139 of 3316.
# Retrived page 1140 of 3316.
# Retrived page 1141 of 3316.
# Retrived page 1142 of 3316.
# Retrived page 1143 of 3316.
# Retrived page 1144 of 3316.
# Retrived page 1145 of 3316.
# Retrived page 1146 of 3316.
# Retrived page 1147 of 3316.
# Retrived page 1148 of 3316.
# Retrived page 1149 of 3316.
# Retrived page 1150 of 3316.
# Retrived page 1151 of 3316.
# Retrived page 1152 of 3316.
# Retrived page 1153 of 3316.
# Retrived page 1154 of 3316.
# Retrived page 1155 of 3316.
# Retrived page 1156 of 3316.
# Retrived page 1157 of 3316.
# Retrived page 1158 of 3316.
# Retrived page 1159 of 3316.
# Retrived page 1160 of 3316.
# Retrived page 1161 of 3316.
# Retrived page 1162 of 3316.
# Retrived page 1163 of 3316.
# Retrived page 1164 of 3316.
# Retrived page 1165 of 3316.
# Retrived page 1166 of 3316.
# Retrived page 1167 of 3316.
# Retrived page 1168 of 3316.
# Retrived page 1169 of 3316.
# Retrived page 1170 of 3316.
# Retrived page 1171 of 3316.
# Retrived page 1172 of 3316.
# Retrived page 1173 of 3316.
# Retrived page 1174 of 3316.
# Retrived page 1175 of 3316.
# Retrived page 1176 of 3316.
# Retrived page 1177 of 3316.
# Retrived page 1178 of 3316.
# Retrived page 1179 of 3316.
# Retrived page 1180 of 3316.
# Retrived page 1181 of 3316.
# Retrived page 1182 of 3316.
# Retrived page 1183 of 3316.
# Retrived page 1184 of 3316.
# Retrived page 1185 of 3316.
# Retrived page 1186 of 3316.
# Retrived page 1187 of 3316.
# Retrived page 1188 of 3316.
# Retrived page 1189 of 3316.
# Retrived page 1190 of 3316.
# Retrived page 1191 of 3316.
# Retrived page 1192 of 3316.
# Retrived page 1193 of 3316.
# Retrived page 1194 of 3316.
# Retrived page 1195 of 3316.
# Retrived page 1196 of 3316.
# Retrived page 1197 of 3316.
# Retrived page 1198 of 3316.
# Retrived page 1199 of 3316.
# Retrived page 1200 of 3316.
# Retrived page 1201 of 3316.
# Retrived page 1202 of 3316.
# Retrived page 1203 of 3316.
# Retrived page 1204 of 3316.
# Retrived page 1205 of 3316.
# Retrived page 1206 of 3316.
# Retrived page 1207 of 3316.
# Retrived page 1208 of 3316.
# Retrived page 1209 of 3316.
# Retrived page 1210 of 3316.
# Retrived page 1211 of 3316.
# Retrived page 1212 of 3316.
# Retrived page 1213 of 3316.
# Retrived page 1214 of 3316.
# Retrived page 1215 of 3316.
# Retrived page 1216 of 3316.
# Retrived page 1217 of 3316.
# Retrived page 1218 of 3316.
# Retrived page 1219 of 3316.
# Retrived page 1220 of 3316.
# Retrived page 1221 of 3316.
# Retrived page 1222 of 3316.
# Retrived page 1223 of 3316.
# Retrived page 1224 of 3316.
# Retrived page 1225 of 3316.
# Retrived page 1226 of 3316.
# Retrived page 1227 of 3316.
# Retrived page 1228 of 3316.
# Retrived page 1229 of 3316.
# Retrived page 1230 of 3316.
# Retrived page 1231 of 3316.
# Retrived page 1232 of 3316.
# Retrived page 1233 of 3316.
# Retrived page 1234 of 3316.
# Retrived page 1235 of 3316.
# Retrived page 1236 of 3316.
# Retrived page 1237 of 3316.
# Retrived page 1238 of 3316.
# Retrived page 1239 of 3316.
# Retrived page 1240 of 3316.
# Retrived page 1241 of 3316.
# Retrived page 1242 of 3316.
# Retrived page 1243 of 3316.
# Retrived page 1244 of 3316.
# Retrived page 1245 of 3316.
# Retrived page 1246 of 3316.
# Retrived page 1247 of 3316.
# Retrived page 1248 of 3316.
# Retrived page 1249 of 3316.
# Retrived page 1250 of 3316.
# Retrived page 1251 of 3316.
# Retrived page 1252 of 3316.
# Retrived page 1253 of 3316.
# Retrived page 1254 of 3316.
# Retrived page 1255 of 3316.
# Retrived page 1256 of 3316.
# Retrived page 1257 of 3316.
# Retrived page 1258 of 3316.
# Retrived page 1259 of 3316.
# Retrived page 1260 of 3316.
# Retrived page 1261 of 3316.
# Retrived page 1262 of 3316.
# Retrived page 1263 of 3316.
# Retrived page 1264 of 3316.
# Retrived page 1265 of 3316.
# Retrived page 1266 of 3316.
# Retrived page 1267 of 3316.
# Retrived page 1268 of 3316.
# Retrived page 1269 of 3316.
# Retrived page 1270 of 3316.
# Retrived page 1271 of 3316.
# Retrived page 1272 of 3316.
# Retrived page 1273 of 3316.
# Retrived page 1274 of 3316.
# Retrived page 1275 of 3316.
# Retrived page 1276 of 3316.
# Retrived page 1277 of 3316.
# Retrived page 1278 of 3316.
# Retrived page 1279 of 3316.
# Retrived page 1280 of 3316.
# Retrived page 1281 of 3316.
# Retrived page 1282 of 3316.
# Retrived page 1283 of 3316.
# Retrived page 1284 of 3316.
# Retrived page 1285 of 3316.
# Retrived page 1286 of 3316.
# Retrived page 1287 of 3316.
# Retrived page 1288 of 3316.
# Retrived page 1289 of 3316.
# Retrived page 1290 of 3316.
# Retrived page 1291 of 3316.
# Retrived page 1292 of 3316.
# Retrived page 1293 of 3316.
# Retrived page 1294 of 3316.
# Retrived page 1295 of 3316.
# Retrived page 1296 of 3316.
# Retrived page 1297 of 3316.
# Retrived page 1298 of 3316.
# Retrived page 1299 of 3316.
# Retrived page 1300 of 3316.
# Retrived page 1301 of 3316.
# Retrived page 1302 of 3316.
# Retrived page 1303 of 3316.
# Retrived page 1304 of 3316.
# Retrived page 1305 of 3316.
# Retrived page 1306 of 3316.
# Retrived page 1307 of 3316.
# Retrived page 1308 of 3316.
# Retrived page 1309 of 3316.
# Retrived page 1310 of 3316.
# Retrived page 1311 of 3316.
# Retrived page 1312 of 3316.
# Retrived page 1313 of 3316.
# Retrived page 1314 of 3316.
# Retrived page 1315 of 3316.
# Retrived page 1316 of 3316.
# Retrived page 1317 of 3316.
# Retrived page 1318 of 3316.
# Retrived page 1319 of 3316.
# Retrived page 1320 of 3316.
# Retrived page 1321 of 3316.
# Retrived page 1322 of 3316.
# Retrived page 1323 of 3316.
# Retrived page 1324 of 3316.
# Retrived page 1325 of 3316.
# Retrived page 1326 of 3316.
# Retrived page 1327 of 3316.
# Retrived page 1328 of 3316.
# Retrived page 1329 of 3316.
# Retrived page 1330 of 3316.
# Retrived page 1331 of 3316.
# Retrived page 1332 of 3316.
# Retrived page 1333 of 3316.
# Retrived page 1334 of 3316.
# Retrived page 1335 of 3316.
# Retrived page 1336 of 3316.
# Retrived page 1337 of 3316.
# Retrived page 1338 of 3316.
# Retrived page 1339 of 3316.
# Retrived page 1340 of 3316.
# Retrived page 1341 of 3316.
# Retrived page 1342 of 3316.
# Retrived page 1343 of 3316.
# Retrived page 1344 of 3316.
# Retrived page 1345 of 3316.
# Retrived page 1346 of 3316.
# Retrived page 1347 of 3316.
# Retrived page 1348 of 3316.
# Retrived page 1349 of 3316.
# Retrived page 1350 of 3316.
# Retrived page 1351 of 3316.
# Retrived page 1352 of 3316.
# Retrived page 1353 of 3316.
# Retrived page 1354 of 3316.
# Retrived page 1355 of 3316.
# Retrived page 1356 of 3316.
# Retrived page 1357 of 3316.
# Retrived page 1358 of 3316.
# Retrived page 1359 of 3316.
# Retrived page 1360 of 3316.
# Retrived page 1361 of 3316.
# Retrived page 1362 of 3316.
# Retrived page 1363 of 3316.
# Retrived page 1364 of 3316.
# Retrived page 1365 of 3316.
# Retrived page 1366 of 3316.
# Retrived page 1367 of 3316.
# Retrived page 1368 of 3316.
# Retrived page 1369 of 3316.
# Retrived page 1370 of 3316.
# Retrived page 1371 of 3316.
# Retrived page 1372 of 3316.
# Retrived page 1373 of 3316.
# Retrived page 1374 of 3316.
# Retrived page 1375 of 3316.
# Retrived page 1376 of 3316.
# Retrived page 1377 of 3316.
# Retrived page 1378 of 3316.
# Retrived page 1379 of 3316.
# Retrived page 1380 of 3316.
# Retrived page 1381 of 3316.
# Retrived page 1382 of 3316.
# Retrived page 1383 of 3316.
# Retrived page 1384 of 3316.
# Retrived page 1385 of 3316.
# Retrived page 1386 of 3316.
# Retrived page 1387 of 3316.
# Retrived page 1388 of 3316.
# Retrived page 1389 of 3316.
# Retrived page 1390 of 3316.
# Retrived page 1391 of 3316.
# Retrived page 1392 of 3316.
# Retrived page 1393 of 3316.
# Retrived page 1394 of 3316.
# Retrived page 1395 of 3316.
# Retrived page 1396 of 3316.
# Retrived page 1397 of 3316.
# Retrived page 1398 of 3316.
# Retrived page 1399 of 3316.
# Retrived page 1400 of 3316.
# Retrived page 1401 of 3316.
# Retrived page 1402 of 3316.
# Retrived page 1403 of 3316.
# Retrived page 1404 of 3316.
# Retrived page 1405 of 3316.
# Retrived page 1406 of 3316.
# Retrived page 1407 of 3316.
# Retrived page 1408 of 3316.
# Retrived page 1409 of 3316.
# Retrived page 1410 of 3316.
# Retrived page 1411 of 3316.
# Retrived page 1412 of 3316.
# Retrived page 1413 of 3316.
# Retrived page 1414 of 3316.
# Retrived page 1415 of 3316.
# Retrived page 1416 of 3316.
# Retrived page 1417 of 3316.
# Retrived page 1418 of 3316.
# Retrived page 1419 of 3316.
# Retrived page 1420 of 3316.
# Retrived page 1421 of 3316.
# Retrived page 1422 of 3316.
# Retrived page 1423 of 3316.
# Retrived page 1424 of 3316.
# Retrived page 1425 of 3316.
# Retrived page 1426 of 3316.
# Retrived page 1427 of 3316.
# Retrived page 1428 of 3316.
# Retrived page 1429 of 3316.
# Retrived page 1430 of 3316.
# Retrived page 1431 of 3316.
# Retrived page 1432 of 3316.
# Retrived page 1433 of 3316.
# Retrived page 1434 of 3316.
# Retrived page 1435 of 3316.
# Retrived page 1436 of 3316.
# Retrived page 1437 of 3316.
# Retrived page 1438 of 3316.
# Retrived page 1439 of 3316.
# Retrived page 1440 of 3316.
# Retrived page 1441 of 3316.
# Retrived page 1442 of 3316.
# Retrived page 1443 of 3316.
# Retrived page 1444 of 3316.
# Retrived page 1445 of 3316.
# Retrived page 1446 of 3316.
# Retrived page 1447 of 3316.
# Retrived page 1448 of 3316.
# Retrived page 1449 of 3316.
# Retrived page 1450 of 3316.
# Retrived page 1451 of 3316.
# Retrived page 1452 of 3316.
# Retrived page 1453 of 3316.
# Retrived page 1454 of 3316.
# Retrived page 1455 of 3316.
# Retrived page 1456 of 3316.
# Retrived page 1457 of 3316.
# Retrived page 1458 of 3316.
# Retrived page 1459 of 3316.
# Retrived page 1460 of 3316.
# Retrived page 1461 of 3316.
# Retrived page 1462 of 3316.
# Retrived page 1463 of 3316.
# Retrived page 1464 of 3316.
# Retrived page 1465 of 3316.
# Retrived page 1466 of 3316.
# Retrived page 1467 of 3316.
# Retrived page 1468 of 3316.
# Retrived page 1469 of 3316.
# Retrived page 1470 of 3316.
# Retrived page 1471 of 3316.
# Retrived page 1472 of 3316.
# Retrived page 1473 of 3316.
# Retrived page 1474 of 3316.
# Retrived page 1475 of 3316.
# Retrived page 1476 of 3316.
# Retrived page 1477 of 3316.
# Retrived page 1478 of 3316.
# Retrived page 1479 of 3316.
# Retrived page 1480 of 3316.
# Retrived page 1481 of 3316.
# Retrived page 1482 of 3316.
# Retrived page 1483 of 3316.
# Retrived page 1484 of 3316.
# Retrived page 1485 of 3316.
# Retrived page 1486 of 3316.
# Retrived page 1487 of 3316.
# Retrived page 1488 of 3316.
# Retrived page 1489 of 3316.
# Retrived page 1490 of 3316.
# Retrived page 1491 of 3316.
# Retrived page 1492 of 3316.
# Retrived page 1493 of 3316.
# Retrived page 1494 of 3316.
# Retrived page 1495 of 3316.
# Retrived page 1496 of 3316.
# Retrived page 1497 of 3316.
# Retrived page 1498 of 3316.
# Retrived page 1499 of 3316.
# Retrived page 1500 of 3316.
# Retrived page 1501 of 3316.
# Retrived page 1502 of 3316.
# Retrived page 1503 of 3316.
# Retrived page 1504 of 3316.
# Retrived page 1505 of 3316.
# Retrived page 1506 of 3316.
# Retrived page 1507 of 3316.
# Retrived page 1508 of 3316.
# Retrived page 1509 of 3316.
# Retrived page 1510 of 3316.
# Retrived page 1511 of 3316.
# Retrived page 1512 of 3316.
# Retrived page 1513 of 3316.
# Retrived page 1514 of 3316.
# Retrived page 1515 of 3316.
# Retrived page 1516 of 3316.
# Retrived page 1517 of 3316.
# Retrived page 1518 of 3316.
# Retrived page 1519 of 3316.
# Retrived page 1520 of 3316.
# Retrived page 1521 of 3316.
# Retrived page 1522 of 3316.
# Retrived page 1523 of 3316.
# Retrived page 1524 of 3316.
# Retrived page 1525 of 3316.
# Retrived page 1526 of 3316.
# Retrived page 1527 of 3316.
# Retrived page 1528 of 3316.
# Retrived page 1529 of 3316.
# Retrived page 1530 of 3316.
# Retrived page 1531 of 3316.
# Retrived page 1532 of 3316.
# Retrived page 1533 of 3316.
# Retrived page 1534 of 3316.
# Retrived page 1535 of 3316.
# Retrived page 1536 of 3316.
# Retrived page 1537 of 3316.
# Retrived page 1538 of 3316.
# Retrived page 1539 of 3316.
# Retrived page 1540 of 3316.
# Retrived page 1541 of 3316.
# Retrived page 1542 of 3316.
# Retrived page 1543 of 3316.
# Retrived page 1544 of 3316.
# Retrived page 1545 of 3316.
# Retrived page 1546 of 3316.
# Retrived page 1547 of 3316.
# Retrived page 1548 of 3316.
# Retrived page 1549 of 3316.
# Retrived page 1550 of 3316.
# Retrived page 1551 of 3316.
# Retrived page 1552 of 3316.
# Retrived page 1553 of 3316.
# Retrived page 1554 of 3316.
# Retrived page 1555 of 3316.
# Retrived page 1556 of 3316.
# Retrived page 1557 of 3316.
# Retrived page 1558 of 3316.
# Retrived page 1559 of 3316.
# Retrived page 1560 of 3316.
# Retrived page 1561 of 3316.
# Retrived page 1562 of 3316.
# Retrived page 1563 of 3316.
# Retrived page 1564 of 3316.
# Retrived page 1565 of 3316.
# Retrived page 1566 of 3316.
# Retrived page 1567 of 3316.
# Retrived page 1568 of 3316.
# Retrived page 1569 of 3316.
# Retrived page 1570 of 3316.
# Retrived page 1571 of 3316.
# Retrived page 1572 of 3316.
# Retrived page 1573 of 3316.
# Retrived page 1574 of 3316.
# Retrived page 1575 of 3316.
# Retrived page 1576 of 3316.
# Retrived page 1577 of 3316.
# Retrived page 1578 of 3316.
# Retrived page 1579 of 3316.
# Retrived page 1580 of 3316.
# Retrived page 1581 of 3316.
# Retrived page 1582 of 3316.
# Retrived page 1583 of 3316.
# Retrived page 1584 of 3316.
# Retrived page 1585 of 3316.
# Retrived page 1586 of 3316.
# Retrived page 1587 of 3316.
# Retrived page 1588 of 3316.
# Retrived page 1589 of 3316.
# Retrived page 1590 of 3316.
# Retrived page 1591 of 3316.
# Retrived page 1592 of 3316.
# Retrived page 1593 of 3316.
# Retrived page 1594 of 3316.
# Retrived page 1595 of 3316.
# Retrived page 1596 of 3316.
# Retrived page 1597 of 3316.
# Retrived page 1598 of 3316.
# Retrived page 1599 of 3316.
# Retrived page 1600 of 3316.
# Retrived page 1601 of 3316.
# Retrived page 1602 of 3316.
# Retrived page 1603 of 3316.
# Retrived page 1604 of 3316.
# Retrived page 1605 of 3316.
# Retrived page 1606 of 3316.
# Retrived page 1607 of 3316.
# Retrived page 1608 of 3316.
# Retrived page 1609 of 3316.
# Retrived page 1610 of 3316.
# Retrived page 1611 of 3316.
# Retrived page 1612 of 3316.
# Retrived page 1613 of 3316.
# Retrived page 1614 of 3316.
# Retrived page 1615 of 3316.
# Retrived page 1616 of 3316.
# Retrived page 1617 of 3316.
# Retrived page 1618 of 3316.
# Retrived page 1619 of 3316.
# Retrived page 1620 of 3316.
# Retrived page 1621 of 3316.
# Retrived page 1622 of 3316.
# Retrived page 1623 of 3316.
# Retrived page 1624 of 3316.
# Retrived page 1625 of 3316.
# Retrived page 1626 of 3316.
# Retrived page 1627 of 3316.
# Retrived page 1628 of 3316.
# Retrived page 1629 of 3316.
# Retrived page 1630 of 3316.
# Retrived page 1631 of 3316.
# Retrived page 1632 of 3316.
# Retrived page 1633 of 3316.
# Retrived page 1634 of 3316.
# Retrived page 1635 of 3316.
# Retrived page 1636 of 3316.
# Retrived page 1637 of 3316.
# Retrived page 1638 of 3316.
# Retrived page 1639 of 3316.
# Retrived page 1640 of 3316.
# Retrived page 1641 of 3316.
# Retrived page 1642 of 3316.
# Retrived page 1643 of 3316.
# Retrived page 1644 of 3316.
# Retrived page 1645 of 3316.
# Retrived page 1646 of 3316.
# Retrived page 1647 of 3316.
# Retrived page 1648 of 3316.
# Retrived page 1649 of 3316.
# Retrived page 1650 of 3316.
# Retrived page 1651 of 3316.
# Retrived page 1652 of 3316.
# Retrived page 1653 of 3316.
# Retrived page 1654 of 3316.
# Retrived page 1655 of 3316.
# Retrived page 1656 of 3316.
# Retrived page 1657 of 3316.
# Retrived page 1658 of 3316.
# Retrived page 1659 of 3316.
# Retrived page 1660 of 3316.
# Retrived page 1661 of 3316.
# Retrived page 1662 of 3316.
# Retrived page 1663 of 3316.
# Retrived page 1664 of 3316.
# Retrived page 1665 of 3316.
# Retrived page 1666 of 3316.
# Retrived page 1667 of 3316.
# Retrived page 1668 of 3316.
# Retrived page 1669 of 3316.
# Retrived page 1670 of 3316.
# Retrived page 1671 of 3316.
# Retrived page 1672 of 3316.
# Retrived page 1673 of 3316.
# Retrived page 1674 of 3316.
# Retrived page 1675 of 3316.
# Retrived page 1676 of 3316.
# Retrived page 1677 of 3316.
# Retrived page 1678 of 3316.
# Retrived page 1679 of 3316.
# Retrived page 1680 of 3316.
# Retrived page 1681 of 3316.
# Retrived page 1682 of 3316.
# Retrived page 1683 of 3316.
# Retrived page 1684 of 3316.
# Retrived page 1685 of 3316.
# Retrived page 1686 of 3316.
# Retrived page 1687 of 3316.
# Retrived page 1688 of 3316.
# Retrived page 1689 of 3316.
# Retrived page 1690 of 3316.
# Retrived page 1691 of 3316.
# Retrived page 1692 of 3316.
# Retrived page 1693 of 3316.
# Retrived page 1694 of 3316.
# Retrived page 1695 of 3316.
# Retrived page 1696 of 3316.
# Retrived page 1697 of 3316.
# Retrived page 1698 of 3316.
# Retrived page 1699 of 3316.
# Retrived page 1700 of 3316.
# Retrived page 1701 of 3316.
# Retrived page 1702 of 3316.
# Retrived page 1703 of 3316.
# Retrived page 1704 of 3316.
# Retrived page 1705 of 3316.
# Retrived page 1706 of 3316.
# Retrived page 1707 of 3316.
# Retrived page 1708 of 3316.
# Retrived page 1709 of 3316.
# Retrived page 1710 of 3316.
# Retrived page 1711 of 3316.
# Retrived page 1712 of 3316.
# Retrived page 1713 of 3316.
# Retrived page 1714 of 3316.
# Retrived page 1715 of 3316.
# Retrived page 1716 of 3316.
# Retrived page 1717 of 3316.
# Retrived page 1718 of 3316.
# Retrived page 1719 of 3316.
# Retrived page 1720 of 3316.
# Retrived page 1721 of 3316.
# Retrived page 1722 of 3316.
# Retrived page 1723 of 3316.
# Retrived page 1724 of 3316.
# Retrived page 1725 of 3316.
# Retrived page 1726 of 3316.
# Retrived page 1727 of 3316.
# Retrived page 1728 of 3316.
# Retrived page 1729 of 3316.
# Retrived page 1730 of 3316.
# Retrived page 1731 of 3316.
# Retrived page 1732 of 3316.
# Retrived page 1733 of 3316.
# Retrived page 1734 of 3316.
# Retrived page 1735 of 3316.
# Retrived page 1736 of 3316.
# Retrived page 1737 of 3316.
# Retrived page 1738 of 3316.
# Retrived page 1739 of 3316.
# Retrived page 1740 of 3316.
# Retrived page 1741 of 3316.
# Retrived page 1742 of 3316.
# Retrived page 1743 of 3316.
# Retrived page 1744 of 3316.
# Retrived page 1745 of 3316.
# Retrived page 1746 of 3316.
# Retrived page 1747 of 3316.
# Retrived page 1748 of 3316.
# Retrived page 1749 of 3316.
# Retrived page 1750 of 3316.
# ...
# Retrived page 2747 of 3316.
# Retrived page 2748 of 3316.
# Retrived page 2749 of 3316.
# Retrived page 2750 of 3316.
# Retrived page 2751 of 3316.
# Retrived page 2752 of 3316.
# Retrived page 2753 of 3316.
# Retrived page 2754 of 3316.
# Retrived page 2755 of 3316.
# Retrived page 2756 of 3316.
# Retrived page 2757 of 3316.
# Retrived page 2758 of 3316.
# Retrived page 2759 of 3316.
# Retrived page 2760 of 3316.
# Retrived page 2761 of 3316.
# Retrived page 2762 of 3316.
# Retrived page 2763 of 3316.
# Retrived page 2764 of 3316.
# Retrived page 2765 of 3316.
# Retrived page 2766 of 3316.
# Retrived page 2767 of 3316.
# Retrived page 2768 of 3316.
# Retrived page 2769 of 3316.
# Retrived page 2770 of 3316.
# Retrived page 2771 of 3316.
# Retrived page 2772 of 3316.
# Retrived page 2773 of 3316.
# Retrived page 2774 of 3316.
# Retrived page 2775 of 3316.
# Retrived page 2776 of 3316.
# Retrived page 2777 of 3316.
# Retrived page 2778 of 3316.
# Retrived page 2779 of 3316.
# Retrived page 2780 of 3316.
# Retrived page 2781 of 3316.
# Retrived page 2782 of 3316.
# Retrived page 2783 of 3316.
# Retrived page 2784 of 3316.
# Retrived page 2785 of 3316.
# Retrived page 2786 of 3316.
# Retrived page 2787 of 3316.
# Retrived page 2788 of 3316.
# Retrived page 2789 of 3316.
# Retrived page 2790 of 3316.
# Retrived page 2791 of 3316.
# Retrived page 2792 of 3316.
# Retrived page 2793 of 3316.
# Retrived page 2794 of 3316.
# Retrived page 2795 of 3316.
# Retrived page 2796 of 3316.
# Retrived page 2797 of 3316.
# Retrived page 2798 of 3316.
# Retrived page 2799 of 3316.
# Retrived page 2800 of 3316.
# Retrived page 2801 of 3316.
# Retrived page 2802 of 3316.
# Retrived page 2803 of 3316.
# Retrived page 2804 of 3316.
# Retrived page 2805 of 3316.
# Retrived page 2806 of 3316.
# Retrived page 2807 of 3316.
# Retrived page 2808 of 3316.
# Retrived page 2809 of 3316.
# Retrived page 2810 of 3316.
# Retrived page 2811 of 3316.
# Retrived page 2812 of 3316.
# Retrived page 2813 of 3316.
# Retrived page 2814 of 3316.
# Retrived page 2815 of 3316.
# Retrived page 2816 of 3316.
# Retrived page 2817 of 3316.
# Retrived page 2818 of 3316.
# Retrived page 2819 of 3316.
# Retrived page 2820 of 3316.
# Retrived page 2821 of 3316.
# Retrived page 2822 of 3316.
# Retrived page 2823 of 3316.
# Retrived page 2824 of 3316.
# Retrived page 2825 of 3316.
# Retrived page 2826 of 3316.
# Retrived page 2827 of 3316.
# Retrived page 2828 of 3316.
# Retrived page 2829 of 3316.
# Retrived page 2830 of 3316.
# Retrived page 2831 of 3316.
# Retrived page 2832 of 3316.
# Retrived page 2833 of 3316.
# Retrived page 2834 of 3316.
# Retrived page 2835 of 3316.
# Retrived page 2836 of 3316.
# Retrived page 2837 of 3316.
# Retrived page 2838 of 3316.
# Retrived page 2839 of 3316.
# Retrived page 2840 of 3316.
# Retrived page 2841 of 3316.
# Retrived page 2842 of 3316.
# Retrived page 2843 of 3316.
# Retrived page 2844 of 3316.
# Retrived page 2845 of 3316.
# Retrived page 2846 of 3316.
# Retrived page 2847 of 3316.
# Retrived page 2848 of 3316.
# Retrived page 2849 of 3316.
# Retrived page 2850 of 3316.
# Retrived page 2851 of 3316.
# Retrived page 2852 of 3316.
# Retrived page 2853 of 3316.
# Retrived page 2854 of 3316.
# Retrived page 2855 of 3316.
# Retrived page 2856 of 3316.
# Retrived page 2857 of 3316.
# Retrived page 2858 of 3316.
# Retrived page 2859 of 3316.
# Retrived page 2860 of 3316.
# Retrived page 2861 of 3316.
# Retrived page 2862 of 3316.
# Retrived page 2863 of 3316.
# Retrived page 2864 of 3316.
# Retrived page 2865 of 3316.
# Retrived page 2866 of 3316.
# Retrived page 2867 of 3316.
# Retrived page 2868 of 3316.
# Retrived page 2869 of 3316.
# Retrived page 2870 of 3316.
# Retrived page 2871 of 3316.
# Retrived page 2872 of 3316.
# Retrived page 2873 of 3316.
# Retrived page 2874 of 3316.
# Retrived page 2875 of 3316.
# Retrived page 2876 of 3316.
# Retrived page 2877 of 3316.
# Retrived page 2878 of 3316.
# Retrived page 2879 of 3316.
# Retrived page 2880 of 3316.
# Retrived page 2881 of 3316.
# Retrived page 2882 of 3316.
# Retrived page 2883 of 3316.
# Retrived page 2884 of 3316.
# Retrived page 2885 of 3316.
# Retrived page 2886 of 3316.
# Retrived page 2887 of 3316.
# Retrived page 2888 of 3316.
# Retrived page 2889 of 3316.
# Retrived page 2890 of 3316.
# Retrived page 2891 of 3316.
# Retrived page 2892 of 3316.
# Retrived page 2893 of 3316.
# Retrived page 2894 of 3316.
# Retrived page 2895 of 3316.
# Retrived page 2896 of 3316.
# Retrived page 2897 of 3316.
# Retrived page 2898 of 3316.
# Retrived page 2899 of 3316.
# Retrived page 2900 of 3316.
# Retrived page 2901 of 3316.
# Retrived page 2902 of 3316.
# Retrived page 2903 of 3316.
# Retrived page 2904 of 3316.
# Retrived page 2905 of 3316.
# Retrived page 2906 of 3316.
# Retrived page 2907 of 3316.
# Retrived page 2908 of 3316.
# Retrived page 2909 of 3316.
# Retrived page 2910 of 3316.
# Retrived page 2911 of 3316.
# Retrived page 2912 of 3316.
# Retrived page 2913 of 3316.
# Retrived page 2914 of 3316.
# Retrived page 2915 of 3316.
# Retrived page 2916 of 3316.
# Retrived page 2917 of 3316.
# Retrived page 2918 of 3316.
# Retrived page 2919 of 3316.
# Retrived page 2920 of 3316.
# Retrived page 2921 of 3316.
# Retrived page 2922 of 3316.
# Retrived page 2923 of 3316.
# Retrived page 2924 of 3316.
# Retrived page 2925 of 3316.
# Retrived page 2926 of 3316.
# Retrived page 2927 of 3316.
# Retrived page 2928 of 3316.
# Retrived page 2929 of 3316.
# Retrived page 2930 of 3316.
# Retrived page 2931 of 3316.
# Retrived page 2932 of 3316.
# Retrived page 2933 of 3316.
# Retrived page 2934 of 3316.
# Retrived page 2935 of 3316.
# Retrived page 2936 of 3316.
# Retrived page 2937 of 3316.
# Retrived page 2938 of 3316.
# Retrived page 2939 of 3316.
# Retrived page 2940 of 3316.
# Retrived page 2941 of 3316.
# Retrived page 2942 of 3316.
# Retrived page 2943 of 3316.
# Retrived page 2944 of 3316.
# Retrived page 2945 of 3316.
# Retrived page 2946 of 3316.
# Retrived page 2947 of 3316.
# Retrived page 2948 of 3316.
# Retrived page 2949 of 3316.
# Retrived page 2950 of 3316.
# Retrived page 2951 of 3316.
# Retrived page 2952 of 3316.
# Retrived page 2953 of 3316.
# Retrived page 2954 of 3316.
# Retrived page 2955 of 3316.
# Retrived page 2956 of 3316.
# Retrived page 2957 of 3316.
# Retrived page 2958 of 3316.
# Retrived page 2959 of 3316.
# Retrived page 2960 of 3316.
# Retrived page 2961 of 3316.
# Retrived page 2962 of 3316.
# Retrived page 2963 of 3316.
# Retrived page 2964 of 3316.
# Retrived page 2965 of 3316.
# Retrived page 2966 of 3316.
# Retrived page 2967 of 3316.
# Retrived page 2968 of 3316.
# Retrived page 2969 of 3316.
# Retrived page 2970 of 3316.
# Retrived page 2971 of 3316.
# Retrived page 2972 of 3316.
# Retrived page 2973 of 3316.
# Retrived page 2974 of 3316.
# Retrived page 2975 of 3316.
# Retrived page 2976 of 3316.
# Retrived page 2977 of 3316.
# Retrived page 2978 of 3316.
# Retrived page 2979 of 3316.
# Retrived page 2980 of 3316.
# Retrived page 2981 of 3316.
# Retrived page 2982 of 3316.
# Retrived page 2983 of 3316.
# Retrived page 2984 of 3316.
# Retrived page 2985 of 3316.
# Retrived page 2986 of 3316.
# Retrived page 2987 of 3316.
# Retrived page 2988 of 3316.
# Retrived page 2989 of 3316.
# Retrived page 2990 of 3316.
# Retrived page 2991 of 3316.
# Retrived page 2992 of 3316.
# Retrived page 2993 of 3316.
# Retrived page 2994 of 3316.
# Retrived page 2995 of 3316.
# Retrived page 2996 of 3316.
# Retrived page 2997 of 3316.
# Retrived page 2998 of 3316.
# Retrived page 2999 of 3316.
# Retrived page 3000 of 3316.
# Retrived page 3001 of 3316.
# Retrived page 3002 of 3316.
# Retrived page 3003 of 3316.
# Retrived page 3004 of 3316.
# Retrived page 3005 of 3316.
# Retrived page 3006 of 3316.
# Retrived page 3007 of 3316.
# Retrived page 3008 of 3316.
# Retrived page 3009 of 3316.
# Retrived page 3010 of 3316.
# Retrived page 3011 of 3316.
# Retrived page 3012 of 3316.
# Retrived page 3013 of 3316.
# Retrived page 3014 of 3316.
# Retrived page 3015 of 3316.
# Retrived page 3016 of 3316.
# Retrived page 3017 of 3316.
# Retrived page 3018 of 3316.
# Retrived page 3019 of 3316.
# Retrived page 3020 of 3316.
# Retrived page 3021 of 3316.
# Retrived page 3022 of 3316.
# Retrived page 3023 of 3316.
# Retrived page 3024 of 3316.
# Retrived page 3025 of 3316.
# Retrived page 3026 of 3316.
# Retrived page 3027 of 3316.
# Retrived page 3028 of 3316.
# Retrived page 3029 of 3316.
# Retrived page 3030 of 3316.
# Retrived page 3031 of 3316.
# Retrived page 3032 of 3316.
# Retrived page 3033 of 3316.
# Retrived page 3034 of 3316.
# Retrived page 3035 of 3316.
# Retrived page 3036 of 3316.
# Retrived page 3037 of 3316.
# Retrived page 3038 of 3316.
# Retrived page 3039 of 3316.
# Retrived page 3040 of 3316.
# Retrived page 3041 of 3316.
# Retrived page 3042 of 3316.
# Retrived page 3043 of 3316.
# Retrived page 3044 of 3316.
# Retrived page 3045 of 3316.
# Retrived page 3046 of 3316.
# Retrived page 3047 of 3316.
# Retrived page 3048 of 3316.
# Retrived page 3049 of 3316.
# Retrived page 3050 of 3316.
# Retrived page 3051 of 3316.
# Retrived page 3052 of 3316.
# Retrived page 3053 of 3316.
# Retrived page 3054 of 3316.
# Retrived page 3055 of 3316.
# Retrived page 3056 of 3316.
# Retrived page 3057 of 3316.
# Retrived page 3058 of 3316.
# Retrived page 3059 of 3316.
# Retrived page 3060 of 3316.
# Retrived page 3061 of 3316.
# Retrived page 3062 of 3316.
# Retrived page 3063 of 3316.
# Retrived page 3064 of 3316.
# Retrived page 3065 of 3316.
# Retrived page 3066 of 3316.
# Retrived page 3067 of 3316.
# Retrived page 3068 of 3316.
# Retrived page 3069 of 3316.
# Retrived page 3070 of 3316.
# Retrived page 3071 of 3316.
# Retrived page 3072 of 3316.
# Retrived page 3073 of 3316.
# Retrived page 3074 of 3316.
# Retrived page 3075 of 3316.
# Retrived page 3076 of 3316.
# Retrived page 3077 of 3316.
# Retrived page 3078 of 3316.
# Retrived page 3079 of 3316.
# Retrived page 3080 of 3316.
# Retrived page 3081 of 3316.
# Retrived page 3082 of 3316.
# Retrived page 3083 of 3316.
# Retrived page 3084 of 3316.
# Retrived page 3085 of 3316.
# Retrived page 3086 of 3316.
# Retrived page 3087 of 3316.
# Retrived page 3088 of 3316.
# Retrived page 3089 of 3316.
# Retrived page 3090 of 3316.
# Retrived page 3091 of 3316.
# Retrived page 3092 of 3316.
# Retrived page 3093 of 3316.
# Retrived page 3094 of 3316.
# Retrived page 3095 of 3316.
# Retrived page 3096 of 3316.
# Retrived page 3097 of 3316.
# Retrived page 3098 of 3316.
# Retrived page 3099 of 3316.
# Retrived page 3100 of 3316.
# Retrived page 3101 of 3316.
# Retrived page 3102 of 3316.
# Retrived page 3103 of 3316.
# Retrived page 3104 of 3316.
# Retrived page 3105 of 3316.
# Retrived page 3106 of 3316.
# Retrived page 3107 of 3316.
# Retrived page 3108 of 3316.
# Retrived page 3109 of 3316.
# Retrived page 3110 of 3316.
# Retrived page 3111 of 3316.
# Retrived page 3112 of 3316.
# Retrived page 3113 of 3316.
# Retrived page 3114 of 3316.
# Retrived page 3115 of 3316.
# Retrived page 3116 of 3316.
# Retrived page 3117 of 3316.
# Retrived page 3118 of 3316.
# Retrived page 3119 of 3316.
# Retrived page 3120 of 3316.
# Retrived page 3121 of 3316.
# Retrived page 3122 of 3316.
# Retrived page 3123 of 3316.
# Retrived page 3124 of 3316.
# Retrived page 3125 of 3316.
# Retrived page 3126 of 3316.
# Retrived page 3127 of 3316.
# Retrived page 3128 of 3316.
# Retrived page 3129 of 3316.
# Retrived page 3130 of 3316.
# Retrived page 3131 of 3316.
# Retrived page 3132 of 3316.
# Retrived page 3133 of 3316.
# Retrived page 3134 of 3316.
# Retrived page 3135 of 3316.
# Retrived page 3136 of 3316.
# Retrived page 3137 of 3316.
# Retrived page 3138 of 3316.
# Retrived page 3139 of 3316.
# Retrived page 3140 of 3316.
# Retrived page 3141 of 3316.
# Retrived page 3142 of 3316.
# Retrived page 3143 of 3316.
# Retrived page 3144 of 3316.
# Retrived page 3145 of 3316.
# Retrived page 3146 of 3316.
# Retrived page 3147 of 3316.
# Retrived page 3148 of 3316.
# Retrived page 3149 of 3316.
# Retrived page 3150 of 3316.
# Retrived page 3151 of 3316.
# Retrived page 3152 of 3316.
# Retrived page 3153 of 3316.
# Retrived page 3154 of 3316.
# Retrived page 3155 of 3316.
# Retrived page 3156 of 3316.
# Retrived page 3157 of 3316.
# Retrived page 3158 of 3316.
# Retrived page 3159 of 3316.
# Retrived page 3160 of 3316.
# Retrived page 3161 of 3316.
# Retrived page 3162 of 3316.
# Retrived page 3163 of 3316.
# Retrived page 3164 of 3316.
# Retrived page 3165 of 3316.
# Retrived page 3166 of 3316.
# Retrived page 3167 of 3316.
# Retrived page 3168 of 3316.
# Retrived page 3169 of 3316.
# Retrived page 3170 of 3316.
# Retrived page 3171 of 3316.
# Retrived page 3172 of 3316.
# Retrived page 3173 of 3316.
# Retrived page 3174 of 3316.
# Retrived page 3175 of 3316.
# Retrived page 3176 of 3316.
# Retrived page 3177 of 3316.
# Retrived page 3178 of 3316.
# Retrived page 3179 of 3316.
# Retrived page 3180 of 3316.
# Retrived page 3181 of 3316.
# Retrived page 3182 of 3316.
# Retrived page 3183 of 3316.
# Retrived page 3184 of 3316.
# Retrived page 3185 of 3316.
# Retrived page 3186 of 3316.
# Retrived page 3187 of 3316.
# Retrived page 3188 of 3316.
# Retrived page 3189 of 3316.
# Retrived page 3190 of 3316.
# Retrived page 3191 of 3316.
# Retrived page 3192 of 3316.
# Retrived page 3193 of 3316.
# Retrived page 3194 of 3316.
# Retrived page 3195 of 3316.
# Retrived page 3196 of 3316.
# Retrived page 3197 of 3316.
# Retrived page 3198 of 3316.
# Retrived page 3199 of 3316.
# Retrived page 3200 of 3316.
# Retrived page 3201 of 3316.
# Retrived page 3202 of 3316.
# Retrived page 3203 of 3316.
# Retrived page 3204 of 3316.
# Retrived page 3205 of 3316.
# Retrived page 3206 of 3316.
# Retrived page 3207 of 3316.
# Retrived page 3208 of 3316.
# Retrived page 3209 of 3316.
# Retrived page 3210 of 3316.
# Retrived page 3211 of 3316.
# Retrived page 3212 of 3316.
# Retrived page 3213 of 3316.
# Retrived page 3214 of 3316.
# Retrived page 3215 of 3316.
# Retrived page 3216 of 3316.
# Retrived page 3217 of 3316.
# Retrived page 3218 of 3316.
# Retrived page 3219 of 3316.
# Retrived page 3220 of 3316.
# Retrived page 3221 of 3316.
# Retrived page 3222 of 3316.
# Retrived page 3223 of 3316.
# Retrived page 3224 of 3316.
# Retrived page 3225 of 3316.
# Retrived page 3226 of 3316.
# Retrived page 3227 of 3316.
# Retrived page 3228 of 3316.
# Retrived page 3229 of 3316.
# Retrived page 3230 of 3316.
# Retrived page 3231 of 3316.
# Retrived page 3232 of 3316.
# Retrived page 3233 of 3316.
# Retrived page 3234 of 3316.
# Retrived page 3235 of 3316.
# Retrived page 3236 of 3316.
# Retrived page 3237 of 3316.
# Retrived page 3238 of 3316.
# Retrived page 3239 of 3316.
# Retrived page 3240 of 3316.
# Retrived page 3241 of 3316.
# Retrived page 3242 of 3316.
# Retrived page 3243 of 3316.
# Retrived page 3244 of 3316.
# Retrived page 3245 of 3316.
# Retrived page 3246 of 3316.
# Retrived page 3247 of 3316.
# Retrived page 3248 of 3316.
# Retrived page 3249 of 3316.
# Retrived page 3250 of 3316.
# Retrived page 3251 of 3316.
# Retrived page 3252 of 3316.
# Retrived page 3253 of 3316.
# Retrived page 3254 of 3316.
# Retrived page 3255 of 3316.
# Retrived page 3256 of 3316.
# Retrived page 3257 of 3316.
# Retrived page 3258 of 3316.
# Retrived page 3259 of 3316.
# Retrived page 3260 of 3316.
# Retrived page 3261 of 3316.
# Retrived page 3262 of 3316.
# Retrived page 3263 of 3316.
# Retrived page 3264 of 3316.
# Retrived page 3265 of 3316.
# Retrived page 3266 of 3316.
# Retrived page 3267 of 3316.
# Retrived page 3268 of 3316.
# Retrived page 3269 of 3316.
# Retrived page 3270 of 3316.
# Retrived page 3271 of 3316.
# Retrived page 3272 of 3316.
# Retrived page 3273 of 3316.
# Retrived page 3274 of 3316.
# Retrived page 3275 of 3316.
# Retrived page 3276 of 3316.
# Retrived page 3277 of 3316.
# Retrived page 3278 of 3316.
# Retrived page 3279 of 3316.
# Retrived page 3280 of 3316.
# Retrived page 3281 of 3316.
# Retrived page 3282 of 3316.
# Retrived page 3283 of 3316.
# Retrived page 3284 of 3316.
# Retrived page 3285 of 3316.
# Retrived page 3286 of 3316.
# Retrived page 3287 of 3316.
# Retrived page 3288 of 3316.
# Retrived page 3289 of 3316.
# Retrived page 3290 of 3316.
# Retrived page 3291 of 3316.
# Retrived page 3292 of 3316.
# Retrived page 3293 of 3316.
# Retrived page 3294 of 3316.
# Retrived page 3295 of 3316.
# Retrived page 3296 of 3316.
# Retrived page 3297 of 3316.
# Retrived page 3298 of 3316.
# Retrived page 3299 of 3316.
# Retrived page 3300 of 3316.
# Retrived page 3301 of 3316.
# Retrived page 3302 of 3316.
# Retrived page 3303 of 3316.
# Retrived page 3304 of 3316.
# Retrived page 3305 of 3316.
# Retrived page 3306 of 3316.
# Retrived page 3307 of 3316.
# Retrived page 3308 of 3316.
# Retrived page 3309 of 3316.
# Retrived page 3310 of 3316.
# Retrived page 3311 of 3316.
# Retrived page 3312 of 3316.
# Retrived page 3313 of 3316.
# Retrived page 3314 of 3316.
# Retrived page 3315 of 3316.
# Retrived page 3316 of 3316.
# 'Query Suceeded'

# %%
SetB.query_response_df.write.format("delta").mode("overwrite").saveAsTable("LH_DFE.raw.set_b")
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 23, Finished, Available, Finished)

# %% [markdown]
# ## Test data set C: A Level and equivalent results

# %%
version = "1.0"
data_set_id = "3bb59201-0d1e-1e74-a745-8f65fe5895cf"
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 25, Finished, Available, Finished)

# %%
SetC = DfE_API(data_set_id, version)
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 26, Finished, Available, Finished)

# %%
print(json.dumps(SetC.data_set_meta_json["indicators"], indent=4))
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 30, Finished, Available, Finished)
# [
#     {
#         "id": "zvUFQ",
#         "column": "retention_pupil_count",
#         "label": "Number of students retained",
#         "decimalPlaces": 0
#     },
#     {
#         "id": "kaNhs",
#         "column": "retention_2ndyr_pupil_count",
#         "label": "Number of students retained (2nd year)",
#         "decimalPlaces": 0
#     },
#     {
#         "id": "u9Mo4",
#         "column": "points_per_entry",
#         "label": "Points per entry",
#         "decimalPlaces": 2
#     },
#     {
#         "id": "XH4fK",
#         "column": "points_per_entry_grade",
#         "label": "Points per entry (grade)",
#         "decimalPlaces": 0
#     },
#     {
#         "id": "TuxPJ",
#         "column": "retention_perc",
#         "label": "Retained",
#         "unit": "%",
#         "decimalPlaces": 2
#     },
#     {
#         "id": "cZO31",
#         "column": "pupil_count",
#         "label": "Total students",
#         "decimalPlaces": 0
#     },
#     {
#         "id": "5Tsdi",
#         "column": "pupil_trigger_count",
#         "label": "Total triggered students",
#         "decimalPlaces": 0
#     }
# ]

# %% [markdown]
# ### Example Query

# %%
data = {
    "indicators": ["zvUFQ", "cZO31", "5Tsdi","kaNhs","u9Mo4","XH4fK", "TuxPJ"]
}
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 31, Finished, Available, Finished)

# %%
SetC.post_data_set_query(data)
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 32, Finished, Available, Finished)
# Retrived page 1 of 23.
# Retrived page 2 of 23.
# Retrived page 3 of 23.
# Retrived page 4 of 23.
# Retrived page 5 of 23.
# Retrived page 6 of 23.
# Retrived page 7 of 23.
# Retrived page 8 of 23.
# Retrived page 9 of 23.
# Retrived page 10 of 23.
# Retrived page 11 of 23.
# Retrived page 12 of 23.
# Retrived page 13 of 23.
# Retrived page 14 of 23.
# Retrived page 15 of 23.
# Retrived page 16 of 23.
# Retrived page 17 of 23.
# Retrived page 18 of 23.
# Retrived page 19 of 23.
# Retrived page 20 of 23.
# Retrived page 21 of 23.
# Retrived page 22 of 23.
# Retrived page 23 of 23.
# 'Query Suceeded'

# %%
display(SetC.query_response_df)
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 33, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 12f3d0a4-87be-4395-9c62-89f2dc615d85)

# %%
SetC.query_response_df.write.format("delta").mode("overwrite").saveAsTable("LH_DFE.raw.set_c")
# Out:
# StatementMeta(, 0629b5ab-3a61-49fd-a407-1d0b1160af0c, 34, Finished, Available, Finished)
